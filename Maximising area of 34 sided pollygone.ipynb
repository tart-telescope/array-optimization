# %%
import torch
import torch.optim as optim
from torch.autograd import Variable
import matplotlib.pyplot as plt
from torch import sqrt
import numpy as np
from matplotlib.animation import FuncAnimation
from IPython import display

# %%
# Define the number of variables
#n = 34

# Create a list of Variables for x and y
#x_variables = [torch.randn(1, requires_grad=True) for _ in range(n)]
#y_variables = [torch.randn(1, requires_grad=True) for _ in range(n)]

# Example: printing the variables
#for i in range(n):
    #print(f"x{i+1}:", x_variables[i].item())

#for i in range(n):
    #print(f"y{i+1}:", y_variables[i].item())

# Plot each set of data
#for i in range(n):
    #plt.plot(x_variables[i].detach().numpy(), y_variables[i].detach().numpy(), 'x', color='red', label=f'Set {i+1}')

    

#plt.xlabel('X')
#plt.ylabel('Y')
#plt.title('Plot of 34 sets of data')
#plt.show()

x1 = Variable(torch.randn(1)*1, requires_grad=True)
y1 = Variable(torch.randn(1)*1, requires_grad=True)
x2 = Variable(torch.randn(1)*1, requires_grad=True)
y2 = Variable(torch.randn(1)*1, requires_grad=True)
x3 = Variable(torch.randn(1)*1, requires_grad=True)
y3 = Variable(torch.randn(1)*1, requires_grad=True)
x4 = Variable(torch.randn(1)*1, requires_grad=True)
y4 = Variable(torch.randn(1)*1, requires_grad=True)
y5 = Variable(torch.randn(1)*1, requires_grad=True)
x5 = Variable(torch.randn(1)*1, requires_grad=True)
x6 = Variable(torch.randn(1)*1, requires_grad=True)
x7 = Variable(torch.randn(1)*1, requires_grad=True)
x8 = Variable(torch.randn(1)*1, requires_grad=True)
x9 = Variable(torch.randn(1)*1, requires_grad=True)
x10 = Variable(torch.randn(1)*1, requires_grad=True)
x11 = Variable(torch.randn(1)*1, requires_grad=True)
x12 = Variable(torch.randn(1)*1, requires_grad=True)
x13 = Variable(torch.randn(1)*1, requires_grad=True)
x14 = Variable(torch.randn(1)*1, requires_grad=True)
x15 = Variable(torch.randn(1)*1, requires_grad=True)
x16 = Variable(torch.randn(1)*1, requires_grad=True)
x17 = Variable(torch.randn(1)*1, requires_grad=True)
x18 = Variable(torch.randn(1)*1, requires_grad=True)
x19 = Variable(torch.randn(1)*1, requires_grad=True)
x20 = Variable(torch.randn(1)*1, requires_grad=True)
x21 = Variable(torch.randn(1)*1, requires_grad=True)
x22 = Variable(torch.randn(1)*1, requires_grad=True)
x23 = Variable(torch.randn(1)*1, requires_grad=True)
x24 = Variable(torch.randn(1)*1, requires_grad=True)
x25 = Variable(torch.randn(1)*1, requires_grad=True)
x26 = Variable(torch.randn(1)*1, requires_grad=True)
x27 = Variable(torch.randn(1)*1, requires_grad=True)
x28 = Variable(torch.randn(1)*1, requires_grad=True)
x29 = Variable(torch.randn(1)*1, requires_grad=True)
x30 = Variable(torch.randn(1)*1, requires_grad=True)
x31 = Variable(torch.randn(1)*1, requires_grad=True)
x32 = Variable(torch.randn(1)*1, requires_grad=True)
x33 = Variable(torch.randn(1)*1, requires_grad=True)
x34 = Variable(torch.randn(1)*1, requires_grad=True)
y6 = Variable(torch.randn(1)*1, requires_grad=True)
y7 = Variable(torch.randn(1)*1, requires_grad=True)
y8 = Variable(torch.randn(1)*1, requires_grad=True)
y9 = Variable(torch.randn(1)*1, requires_grad=True)
y10 = Variable(torch.randn(1)*1, requires_grad=True)
y11 = Variable(torch.randn(1)*1, requires_grad=True)
y12 = Variable(torch.randn(1)*1, requires_grad=True)
y13 = Variable(torch.randn(1)*1, requires_grad=True)
y14 = Variable(torch.randn(1)*1, requires_grad=True)
y15 = Variable(torch.randn(1)*1, requires_grad=True)
y16 = Variable(torch.randn(1)*1, requires_grad=True)
y17 = Variable(torch.randn(1)*1, requires_grad=True)
y18 = Variable(torch.randn(1)*1, requires_grad=True)
y19 = Variable(torch.randn(1)*1, requires_grad=True)
y20 = Variable(torch.randn(1)*1, requires_grad=True)
y21 = Variable(torch.randn(1)*1, requires_grad=True)
y22 = Variable(torch.randn(1)*1, requires_grad=True)
y23 = Variable(torch.randn(1)*1, requires_grad=True)
y24 = Variable(torch.randn(1)*1, requires_grad=True)
y25 = Variable(torch.randn(1)*1, requires_grad=True)
y26 = Variable(torch.randn(1)*1, requires_grad=True)
y27 = Variable(torch.randn(1)*1, requires_grad=True)
y28 = Variable(torch.randn(1)*1, requires_grad=True)
y29 = Variable(torch.randn(1)*1, requires_grad=True)
y30 = Variable(torch.randn(1)*1, requires_grad=True)
y31 = Variable(torch.randn(1)*1, requires_grad=True)
y32 = Variable(torch.randn(1)*1, requires_grad=True)
y33 = Variable(torch.randn(1)*1, requires_grad=True)
y34 = Variable(torch.randn(1)*1, requires_grad=True)

plt.plot(x1.detach().numpy(), y1.detach().numpy(), 'x',color='red',label='Starting locations')
plt.plot(x2.detach().numpy(), y2.detach().numpy(), 'x',color='red')
plt.plot(x3.detach().numpy(), y3.detach().numpy(), 'x',color='red')
plt.plot(x4.detach().numpy(), y4.detach().numpy(), 'x',color='red')
plt.plot(x5.detach().numpy(), y5.detach().numpy(), 'x',color='red')
plt.plot(x6.detach().numpy(), y6.detach().numpy(), 'x',color='red')
plt.plot(x7.detach().numpy(), y7.detach().numpy(), 'x',color='red')
plt.plot(x8.detach().numpy(), y8.detach().numpy(), 'x',color='red')
plt.plot(x9.detach().numpy(), y9.detach().numpy(), 'x',color='red')
plt.plot(x10.detach().numpy(), y10.detach().numpy(), 'x',color='red')
plt.plot(x11.detach().numpy(), y11.detach().numpy(), 'x',color='red')
plt.plot(x12.detach().numpy(), y12.detach().numpy(), 'x',color='red')
plt.plot(x13.detach().numpy(), y13.detach().numpy(), 'x',color='red')
plt.plot(x14.detach().numpy(), y14.detach().numpy(), 'x',color='red')
plt.plot(x15.detach().numpy(), y15.detach().numpy(), 'x',color='red')
plt.plot(x16.detach().numpy(), y16.detach().numpy(), 'x',color='red')
plt.plot(x17.detach().numpy(), y17.detach().numpy(), 'x',color='red')
plt.plot(x18.detach().numpy(), y18.detach().numpy(), 'x',color='red')
plt.plot(x19.detach().numpy(), y19.detach().numpy(), 'x',color='red')
plt.plot(x20.detach().numpy(), y20.detach().numpy(), 'x',color='red')
plt.plot(x21.detach().numpy(), y21.detach().numpy(), 'x',color='red')
plt.plot(x22.detach().numpy(), y22.detach().numpy(), 'x',color='red')
plt.plot(x23.detach().numpy(), y23.detach().numpy(), 'x',color='red')
plt.plot(x24.detach().numpy(), y24.detach().numpy(), 'x',color='red')
plt.plot(x25.detach().numpy(), y25.detach().numpy(), 'x',color='red')
plt.plot(x26.detach().numpy(), y26.detach().numpy(), 'x',color='red')
plt.plot(x27.detach().numpy(), y27.detach().numpy(), 'x',color='red')
plt.plot(x28.detach().numpy(), y28.detach().numpy(), 'x',color='red')
plt.plot(x29.detach().numpy(), y29.detach().numpy(), 'x',color='red')
plt.plot(x30.detach().numpy(), y30.detach().numpy(), 'x',color='red')
plt.plot(x31.detach().numpy(), y31.detach().numpy(), 'x',color='red')
plt.plot(x32.detach().numpy(), y32.detach().numpy(), 'x',color='red')
plt.plot(x33.detach().numpy(), y33.detach().numpy(), 'x',color='red')
plt.plot(x34.detach().numpy(), y34.detach().numpy(), 'x',color='red')

print(x1.detach().numpy(), y1.detach().numpy(), 'x')
print(x2.detach().numpy(), y2.detach().numpy(), 'x')
print(x3.detach().numpy(), y3.detach().numpy(), 'x')
print(x4.detach().numpy(), y4.detach().numpy(), 'x')
print(x5.detach().numpy(), y5.detach().numpy(), 'x')
print(x6.detach().numpy(), y6.detach().numpy(), 'x')
print(x7.detach().numpy(), y7.detach().numpy(), 'x')
print(x8.detach().numpy(), y8.detach().numpy(), 'x')
print(x9.detach().numpy(), y9.detach().numpy(), 'x')
print(x10.detach().numpy(), y10.detach().numpy(), 'x')
print(x11.detach().numpy(), y11.detach().numpy(), 'x')
print(x12.detach().numpy(), y12.detach().numpy(), 'x')
print(x13.detach().numpy(), y13.detach().numpy(), 'x')
print(x14.detach().numpy(), y14.detach().numpy(), 'x')
print(x15.detach().numpy(), y15.detach().numpy(), 'x')
print(x16.detach().numpy(), y16.detach().numpy(), 'x')
print(x17.detach().numpy(), y17.detach().numpy(), 'x')
print(x18.detach().numpy(), y18.detach().numpy(), 'x')
print(x19.detach().numpy(), y19.detach().numpy(), 'x')
print(x20.detach().numpy(), y20.detach().numpy(), 'x')
print(x21.detach().numpy(), y21.detach().numpy(), 'x')
print(x22.detach().numpy(), y22.detach().numpy(), 'x')
print(x23.detach().numpy(), y23.detach().numpy(), 'x')
print(x24.detach().numpy(), y24.detach().numpy(), 'x')
print(x25.detach().numpy(), y25.detach().numpy(), 'x')
print(x26.detach().numpy(), y26.detach().numpy(), 'x')
print(x27.detach().numpy(), y27.detach().numpy(), 'x')
print(x28.detach().numpy(), y28.detach().numpy(), 'x')
print(x29.detach().numpy(), y29.detach().numpy(), 'x')
print(x30.detach().numpy(), y30.detach().numpy(), 'x')
print(x31.detach().numpy(), y31.detach().numpy(), 'x')
print(x32.detach().numpy(), y32.detach().numpy(), 'x')
print(x33.detach().numpy(), y33.detach().numpy(), 'x')
print(x34.detach().numpy(), y34.detach().numpy(), 'x')



def compute_area(x1, y1, x2, y2, x3, y3, x4, y4, x5, y5, x6, y6,  x7, y7, x8, y8, x9, y9, x10, y10, x11, y11, x12, y12, x13, y13, x14, y14, x15, y15, x16, y16, x17, y17, x18, y18, x19, y19, x20, y20, x21, y21, x22, y22, x23, y23, x24, y24, x25, y25, x26, y26, x27, y27, x28, y28, x29, y29, x30, y30, x31, y31, x32, y32, x33, y33, x34, y34):


   #  area = 0.5 * |x1*y2 -x1*y4 -x3*y2 + x3*y4 -y1*x2 +y1*x4 +y3*x2 -y3*x4|

        return 0.5 * torch.abs((x1*y2 - y1*x2)+(x2*y3 - y2*x3)+(x3*y4 -y3*x4)+(x4*y5-y4*x5)+(x5*y6-y5*x6)+(x6*y7-y6*x7)+(x7*y8-y7*x8)+(x8*y9-y8*x9)+(x9*y10-y9*x10)+(x10*y11-y10*x11)+(x11*y12-y11*x12)+(x12*y13-y12*x13)+(x13*y14-y13*x14)+(x14*y15-y14*x15)+(x15*y16-y15*x16)+(x16*y17-y16*x17)+(x17*y18-y17*x18)+(x18*y19-y18*x19)+(x19*y20-y19*x20)+(x20*y21-y20*x21)+(x21*y22-y21*x22)+(x22*y23-y22*x23)+(x23*y24-y23*x24)+(x24*y25-y24*x25)+(x25*y26-y25*x26)+(x26*y27-y26*x27)+(x27*y28-y27*x28)+(x28*y29-y28*x29)+(x29*y30-y29*x30)+(x30*y31-y30*x31)+(x31*y32-y31*x32)+(x32*y33-y32*x33)+(x33*y34-y33*x34)+(x34*y1-y34*x1))
    


def compute_perimeter(x1, y1, x2, y2, x3, y3, x4, y4, x5, y5, x6, y6,  x7, y7, x8, y8, x9, y9, x10, y10, x11, y11, x12, y12, x13, y13, x14, y14, x15, y15, x16, y16, x17, y17, x18, y18, x19, y19, x20, y20, x21, y21, x22, y22, x23, y23, x24, y24, x25, y25, x26, y26, x27, y27, x28, y28, x29, y29, x30, y30, x31, y31, x32, y32, x33, y33, x34, y34):
   
    s1 = torch.sqrt((x2 - x1)**2 + (y2 - y1)**2)
    s2 = torch.sqrt((x3 - x2)**2 + (y3 - y2)**2)
    s3 = torch.sqrt((x4 - x3)**2 + (y4 - y3)**2)
    s4 = torch.sqrt((x5 - x4)**2 + (y5 - y4)**2)
    s5 = torch.sqrt((x6 - x5)**2 + (y6 - y5)**2)
    s6 = torch.sqrt((x7 - x6)**2 + (y7 - y6)**2)
    s7 = torch.sqrt((x8 - x7)**2 + (y8 - y7)**2)
    s8 = torch.sqrt((x9 - x8)**2 + (y9- y8)**2)
    s9 = torch.sqrt((x10 - x9)**2 + (y10 - y9)**2)
    s10 = torch.sqrt((x11 - x10)**2 + (y11 - y10)**2)
    s11 = torch.sqrt((x12 - x11)**2 + (y12 - y11)**2)
    s12= torch.sqrt((x13 - x12)**2 + (y13 - y12)**2)
    s13= torch.sqrt((x14 - x13)**2 + (y14 - y13)**2)
    s14= torch.sqrt((x15 - x14)**2 + (y15 - y14)**2)
    s15= torch.sqrt((x16 - x15)**2 + (y16 - y15)**2)
    s16= torch.sqrt((x17 - x16)**2 + (y17- y16)**2)
    s17= torch.sqrt((x18 - x17)**2 + (y18- y17)**2)
    s18= torch.sqrt((x19 - x18)**2 + (y19- y18)**2)
    s19= torch.sqrt((x20 - x19)**2 + (y20- y19)**2)
    s20= torch.sqrt((x21 - x20)**2 + (y21 - y20)**2)
    s21= torch.sqrt((x22 - x21)**2 + (y22 - y21)**2)
    s22= torch.sqrt((x23 - x22)**2 + (y23 - y22)**2)
    s23= torch.sqrt((x24 - x23)**2 + (y24 - y23)**2)
    s24= torch.sqrt((x25 - x24)**2 + (y25 - y24)**2)
    s25= torch.sqrt((x26 - x25)**2 + (y26 - y25)**2)
    s26= torch.sqrt((x27 - x26)**2 + (y27- y26)**2)
    s27= torch.sqrt((x28 - x27)**2 + (y28- y27)**2)
    s28= torch.sqrt((x29- x28)**2 + (y29- y28)**2)
    s29= torch.sqrt((x30- x29)**2 + (y30 - y29)**2)
    s30= torch.sqrt((x31 - x30)**2 + (y31 - y30)**2)
    s31= torch.sqrt((x32 - x31)**2 + (y32 - y31)**2)
    s32= torch.sqrt((x33 - x32)**2 + (y33 - y32)**2)
    s33= torch.sqrt((x34 - x33)**2 + (y34 - y33)**2)
    s34= torch.sqrt((x1 - x34)**2 + (y1 - y34)**2)
 
    return s1 + s2 + s3 + s4 + s5 + s6 + s7 + s8 + s9 + s10 + s11 + s12 + s13 + s14 + s15 + s16 + s17 + s18 + s19 + s20 + s21 + s22 + s23 + s24 + s25 + s26 + s27 + s28 + s29 + s30 +s31 + s32 + s33 + s34 



optimizer = optim.RMSprop([x1, y1, x2, y2, x3, y3, x4, y4, x5, y5, x6, y6, x7, y7, x8, y8, x9, y9, x10, y10, x11, y11, x12, y12, x13, y13, x14, y14, x15, y15, x16, y16, x17, y17, x18, y18, x19, y19, x20, y20, x21, y21, x22, y22, x23, y23, x24, y24, x25, y25, x26, y26, x27, y27, x28, y28, x29, y29, x30, y30, x31, y31, x32, y32, x33, y33, x34, y34], lr=.008)
#, momentum=0
steps = 500000

max_perimeter = 100

loss_history = []

# Optimization loop
for step in range(steps):
    # Compute area
    area = compute_area(x1, y1, x2, y2, x3, y3, x4, y4, x5, y5, x6, y6,  x7, y7, x8, y8, x9, y9, x10, y10, x11, y11, x12, y12, x13, y13, x14, y14, x15, y15, x16, y16, x17, y17, x18, y18, x19, y19, x20, y20, x21, y21, x22, y22, x23, y23, x24, y24, x25, y25, x26, y26, x27, y27, x28, y28, x29, y29, x30, y30, x31, y31, x32, y32, x33, y33, x34, y34)
    
    # Compute perimeter
    perimeter = compute_perimeter(x1, y1, x2, y2, x3, y3, x4, y4, x5, y5, x6, y6,  x7, y7, x8, y8, x9, y9, x10, y10, x11, y11, x12, y12, x13, y13, x14, y14, x15, y15, x16, y16, x17, y17, x18, y18, x19, y19, x20, y20, x21, y21, x22, y22, x23, y23, x24, y24, x25, y25, x26, y26, x27, y27, x28, y28, x29, y29, x30, y30, x31, y31, x32, y32, x33, y33, x34, y34)
    
    # apply a penalty if peremter of 100 units is exceeded (not really confindent in this step and the next step)
    perimeter_penalty = (torch.max(torch.tensor(0.), ((perimeter)**2 - (max_perimeter)**2))) #hmmmm
    
    # loss function
    loss = -area + perimeter_penalty**1
    #(torch.log(1/area) + perimeter_penalty**1)
    #-area + perimeter_penalty**1
    #(torch.log((1/area) + 1*perimeter_penalty**2))
    #(torch.log(1/area) + perimeter_penalty**1)  # hmmmm
    #loss = -area + perimeter_penalty**1
    # 2*perimeter_penalty - area
    
    
    # Zero gradients
    optimizer.zero_grad()
    
    # Compute gradients
    loss.backward()
    
    # Update parameters
    optimizer.step()

    loss_history.append(loss.item())

    if step % 100 == 0:
        print(f'Step {step}: loss_history = {loss.item()}') # Prints a value for loss function once every hundred iterations

optimized_x1 = x1.item()
optimized_y1 = y1.item()
optimized_x2 = x2.item()
optimized_y2 = y2.item()
optimized_x3 = x3.item()
optimized_y3 = y3.item()
optimized_x4 = x4.item()
optimized_y4 = y4.item()
optimized_x5 = x5.item()
optimized_y5 = y5.item()

optimized_x6 = x6.item()
optimized_x7 = x7.item()
optimized_x8 = x8.item()
optimized_x9 = x9.item()
optimized_x10 = x10.item()
optimized_x11 = x11.item()
optimized_x12 = x12.item()
optimized_x13 = x13.item()
optimized_x14 = x14.item()
optimized_x15 = x15.item()
optimized_x16 = x16.item()
optimized_x17 = x17.item()
optimized_x18 = x18.item()
optimized_x19 = x19.item()
optimized_x20 = x20.item()
optimized_x21 = x21.item()
optimized_x22 = x22.item()
optimized_x23 = x23.item()
optimized_x24 = x24.item()
optimized_x25 = x25.item()
optimized_x26 = x26.item()
optimized_x27 = x27.item()
optimized_x28 = x28.item()
optimized_x29 = x29.item()
optimized_x30 = x30.item()
optimized_x31 = x31.item()
optimized_x32 = x32.item()
optimized_x33 = x33.item()
optimized_x34 = x34.item()

optimized_y6 = y6.item()
optimized_y7 = y7.item()
optimized_y8 = y8.item()
optimized_y9 = y9.item()
optimized_y10 = y10.item()
optimized_y11 = y11.item()
optimized_y12 = y12.item()
optimized_y13 = y13.item()
optimized_y14 = y14.item()
optimized_y15 = y15.item()
optimized_y16 = y16.item()
optimized_y17 = y17.item()
optimized_y18 = y18.item()
optimized_y19 = y19.item()
optimized_y20 = y20.item()
optimized_y21 = y21.item()
optimized_y22 = y22.item()
optimized_y23 = y23.item()
optimized_y24 = y24.item()
optimized_y25 = y25.item()
optimized_y26 = y26.item()
optimized_y27 = y27.item()
optimized_y28 = y28.item()
optimized_y29 = y29.item()
optimized_y30 = y30.item()
optimized_y31 = y31.item()
optimized_y32 = y32.item()
optimized_y33 = y33.item()
optimized_y34 = y34.item()

# Print the optimized coords, area and perimeter (should be a square)
print("Optimized Coordinates:")
print("Vertex 1: ({}, {})".format(optimized_x1, optimized_y1))
print("Vertex 2: ({}, {})".format(optimized_x2, optimized_y2))
print("Vertex 3: ({}, {})".format(optimized_x3, optimized_y3))
print("Vertex 4: ({}, {})".format(optimized_x4, optimized_y4))
print("Vertex 5: ({}, {})".format(optimized_x5, optimized_y5))
print("Vertex 6: ({}, {})".format(optimized_x6, optimized_y6))
print("Vertex 7: ({}, {})".format(optimized_x7, optimized_y7))
print("Vertex 8: ({}, {})".format(optimized_x8, optimized_y8))
print("Vertex 9: ({}, {})".format(optimized_x9, optimized_y9))
print("Vertex 10: ({}, {})".format(optimized_x10, optimized_y10))
print("Vertex 11: ({}, {})".format(optimized_x11, optimized_y11))
print("Vertex 12: ({}, {})".format(optimized_x12, optimized_y12))
print("Vertex 13: ({}, {})".format(optimized_x13, optimized_y13))
print("Vertex 14: ({}, {})".format(optimized_x14, optimized_y14))
print("Vertex 15: ({}, {})".format(optimized_x15, optimized_y15))
print("Vertex 16: ({}, {})".format(optimized_x16, optimized_y16))
print("Vertex 17: ({}, {})".format(optimized_x17, optimized_y17))
print("Vertex 18: ({}, {})".format(optimized_x18, optimized_y18))
print("Vertex 19: ({}, {})".format(optimized_x19, optimized_y19))
print("Vertex 20: ({}, {})".format(optimized_x20, optimized_y20))
print("Vertex 21: ({}, {})".format(optimized_x21, optimized_y21))
print("Vertex 22: ({}, {})".format(optimized_x22, optimized_y22))
print("Vertex 23: ({}, {})".format(optimized_x23, optimized_y23))
print("Vertex 24: ({}, {})".format(optimized_x24, optimized_y24))
print("Vertex 25: ({}, {})".format(optimized_x25, optimized_y25))
print("Vertex 26: ({}, {})".format(optimized_x26, optimized_y26))
print("Vertex 27: ({}, {})".format(optimized_x27, optimized_y27))
print("Vertex 28: ({}, {})".format(optimized_x28, optimized_y28))
print("Vertex 29: ({}, {})".format(optimized_x29, optimized_y29))
print("Vertex 30: ({}, {})".format(optimized_x30, optimized_y30))
print("Vertex 31: ({}, {})".format(optimized_x31, optimized_y31))
print("Vertex 32: ({}, {})".format(optimized_x32, optimized_y32))
print("Vertex 33: ({}, {})".format(optimized_x33, optimized_y33))
print("Vertex 34: ({}, {})".format(optimized_x34, optimized_y34))

print("Optimized Perimeter: {:.4f}".format(compute_perimeter(x1, y1, x2, y2, x3, y3, x4, y4, x5, y5, x6, y6,  x7, y7, x8, y8, x9, y9, x10, y10, x11, y11, x12, y12, x13, y13, x14, y14, x15, y15, x16, y16, x17, y17, x18, y18, x19, y19, x20, y20, x21, y21, x22, y22, x23, y23, x24, y24, x25, y25, x26, y26, x27, y27, x28, y28, x29, y29, x30, y30, x31, y31, x32, y32, x33, y33, x34, y34).item()))
print("Optimized Area: {:.4f}".format(compute_area(x1, y1, x2, y2, x3, y3, x4, y4, x5, y5, x6, y6,  x7, y7, x8, y8, x9, y9, x10, y10, x11, y11, x12, y12, x13, y13, x14, y14, x15, y15, x16, y16, x17, y17, x18, y18, x19, y19, x20, y20, x21, y21, x22, y22, x23, y23, x24, y24, x25, y25, x26, y26, x27, y27, x28, y28, x29, y29, x30, y30, x31, y31, x32, y32, x33, y33, x34, y34).item()))
print("Theoretical maximum = (aprox 795)")


plt.gca().set_aspect('equal', adjustable='box')
plt.plot(x1.item(), y1.item(), 'o',color='black', label='final locations' )
plt.plot(x2.item(), y2.item(), 'o' ,color='black')
plt.plot(x3.item(), y3.item(), 'o',color='black')
plt.plot(x4.item(), y4.item(),'o',color='black')
plt.plot(x5.item(), y5.item(),'o',color='black')
plt.plot(x6.item(), y6.item(), 'o',color='black')
plt.plot(x7.item(), y7.item(), 'o',color='black')
plt.plot(x8.item(), y8.item(), 'o',color='black')
plt.plot(x9.item(), y9.item(),'o',color='black')
plt.plot(x10.item(), y10.item(),'o',color='black')
plt.plot(x11.item(), y11.item(), 'o' ,color='black')
plt.plot(x12.item(), y12.item(), 'o' ,color='black')
plt.plot(x13.item(), y13.item(), 'o',color='black')
plt.plot(x14.item(), y14.item(),'o',color='black')
plt.plot(x15.item(), y15.item(),'o',color='black')
plt.plot(x16.item(), y16.item(), 'o',color='black')
plt.plot(x17.item(), y17.item(), 'o',color='black')
plt.plot(x18.item(), y18.item(), 'o',color='black')
plt.plot(x19.item(), y19.item(),'o',color='black')
plt.plot(x20.item(), y20.item(),'o',color='black')
plt.plot(x21.item(), y21.item(), 'o' ,color='black')
plt.plot(x22.item(), y22.item(), 'o' ,color='black')
plt.plot(x23.item(), y23.item(), 'o',color='black')
plt.plot(x24.item(), y24.item(),'o',color='black')
plt.plot(x25.item(), y25.item(),'o',color='black')
plt.plot(x26.item(), y26.item(), 'o',color='black')
plt.plot(x27.item(), y27.item(), 'o',color='black')
plt.plot(x28.item(), y28.item(), 'o',color='black')
plt.plot(x29.item(), y29.item(),'o',color='black')
plt.plot(x30.item(), y30.item(),'o',color='black')
plt.plot(x31.item(), y31.item(), 'o' ,color='black')
plt.plot(x32.item(), y32.item(), 'o' ,color='black')
plt.plot(x33.item(), y33.item(), 'o',color='black')
plt.plot(x34.item(), y34.item(),'o',color='black')
plt.xlim(-30, 30)
plt.ylim(-30, 30)
plt.title("Optimising Area of a 34 Sided Pollygon While Constraining the Perimeter")
plt.xlabel('length units')
plt.ylabel('length units')
plt.legend()
plt.grid(color='gray', linestyle='-', linewidth=0.5)
plt.savefig("34_inital_and_final_coords_RMSprop_500000its_lr0.0008.pdf")
plt.show()
# Out:
# [-0.55885977] [0.08767595] x
# [-2.041] [-1.4650692] x
# [0.9356777] [1.2568171] x
# [-0.32091737] [-0.9704816] x
# [0.10684515] [-0.56305146] x
# [1.0906501] [-0.20058165] x
# [-0.3371521] [-0.19990093] x
# [1.1828768] [2.581332] x
# [-0.71170336] [-0.36550716] x
# [1.2869068] [0.93997556] x
# [1.465273] [0.6810123] x
# [-0.50402206] [0.5548548] x
# [1.3808063] [-0.50489] x
# [-0.7520432] [-0.81535876] x
# [-1.2182406] [0.31130192] x
# [-2.4484704] [-0.8478236] x
# [0.08123958] [-2.509702] x
# [-0.22906645] [1.1846304] x
# [2.76022] [-0.60472715] x
# [-0.09859098] [0.10781027] x
# [1.0057011] [-0.1918607] x
# [-0.33470923] [-1.6298578] x
# [-1.4570415] [0.66641396] x
# [-1.1972889] [1.1740757] x
# [2.0066118] [0.66785586] x
# [-0.49047065] [0.43674687] x
# [1.1452354] [0.7027405] x
# [-0.18667682] [0.28137994] x
# [-0.67398363] [-1.3478874] x
# [-0.40923753] [0.3868211] x
# [1.2290974] [-0.24477796] x
# [0.5873644] [0.06304828] x
# [0.4177248] [0.18149613] x
# [-1.8672526] [-2.1102076] x
# Step 0: loss_history = -3.7334649562835693
# Step 100: loss_history = -50.92821502685547
# Step 200: loss_history = -56.990421295166016
# Step 300: loss_history = -64.01690673828125
# Step 400: loss_history = -66.80010986328125
# Step 500: loss_history = -70.14998626708984
# Step 600: loss_history = -78.29486083984375
# Step 700: loss_history = -80.67559814453125
# Step 800: loss_history = -83.7010269165039
# Step 900: loss_history = -86.48983001708984
# Step 1000: loss_history = -89.01235961914062
# Step 1100: loss_history = -91.65982055664062
# Step 1200: loss_history = -94.40765380859375
# Step 1300: loss_history = -97.30225372314453
# Step 1400: loss_history = -100.37152099609375
# Step 1500: loss_history = -103.25391387939453
# Step 1600: loss_history = -106.29732513427734
# Step 1700: loss_history = -109.40335845947266
# Step 1800: loss_history = -112.60846710205078
# Step 1900: loss_history = -115.98033905029297
# Step 2000: loss_history = -113.55381774902344
# Step 2100: loss_history = -116.79515838623047
# Step 2200: loss_history = -120.28971862792969
# Step 2300: loss_history = -124.07464599609375
# Step 2400: loss_history = -128.15013122558594
# Step 2500: loss_history = -132.53717041015625
# Step 2600: loss_history = -130.48944091796875
# Step 2700: loss_history = -134.6582794189453
# Step 2800: loss_history = -139.1415557861328
# Step 2900: loss_history = -143.99221801757812
# Step 3000: loss_history = -142.74334716796875
# Step 3100: loss_history = -147.3992919921875
# Step 3200: loss_history = -152.51593017578125
# Step 3300: loss_history = -151.5481414794922
# Step 3400: loss_history = -156.66078186035156
# Step 3500: loss_history = -156.09307861328125
# Step 3600: loss_history = -161.45584106445312
# Step 3700: loss_history = -161.05850219726562
# Step 3800: loss_history = -166.76658630371094
# Step 3900: loss_history = -166.47145080566406
# Step 4000: loss_history = -166.6898651123047
# Step 4100: loss_history = -172.51966857910156
# Step 4200: loss_history = -172.57855224609375
# Step 4300: loss_history = -178.83546447753906
# Step 4400: loss_history = -178.76478576660156
# Step 4500: loss_history = -179.13702392578125
# Step 4600: loss_history = -185.56871032714844
# Step 4700: loss_history = -185.9510955810547
# Step 4800: loss_history = -186.7786102294922
# Step 4900: loss_history = -193.55056762695312
# Step 5000: loss_history = -194.42677307128906
# Step 5100: loss_history = -195.78558349609375
# Step 5200: loss_history = -203.0148162841797
# Step 5300: loss_history = -204.43882751464844
# Step 5400: loss_history = -206.32156372070312
# Step 5500: loss_history = -214.17343139648438
# Step 5600: loss_history = -216.11965942382812
# Step 5700: loss_history = -218.46157836914062
# Step 5800: loss_history = -221.1599884033203
# Step 5900: loss_history = -229.57545471191406
# Step 6000: loss_history = -232.24342346191406
# Step 6100: loss_history = -235.1769561767578
# Step 6200: loss_history = -238.1977996826172
# Step 6300: loss_history = -241.44793701171875
# Step 6400: loss_history = -244.8565216064453
# Step 6500: loss_history = -248.46316528320312
# Step 6600: loss_history = -252.21942138671875
# Step 6700: loss_history = -256.1737060546875
# Step 6800: loss_history = -260.3427429199219
# Step 6900: loss_history = -264.74530029296875
# Step 7000: loss_history = -269.31646728515625
# Step 7100: loss_history = -274.1028137207031
# Step 7200: loss_history = -273.5694885253906
# Step 7300: loss_history = -278.5709228515625
# Step 7400: loss_history = -283.76763916015625
# Step 7500: loss_history = -289.1535339355469
# Step 7600: loss_history = -294.8182678222656
# Step 7700: loss_history = -295.09942626953125
# Step 7800: loss_history = -300.9169921875
# Step 7900: loss_history = -307.03265380859375
# Step 8000: loss_history = -307.9130554199219
# Step 8100: loss_history = -314.3102722167969
# Step 8200: loss_history = -315.6916809082031
# Step 8300: loss_history = -322.41058349609375
# Step 8400: loss_history = -324.2035217285156
# Step 8500: loss_history = -331.28875732421875
# Step 8600: loss_history = -333.45965576171875
# Step 8700: loss_history = -336.0112609863281
# Step 8800: loss_history = -343.4940490722656
# Step 8900: loss_history = -346.38958740234375
# Step 9000: loss_history = -351.2894592285156
# Step 9100: loss_history = -357.65509033203125
# Step 9200: loss_history = -361.13128662109375
# Step 9300: loss_history = -364.8803405761719
# Step 9400: loss_history = -370.9835510253906
# Step 9500: loss_history = -377.773681640625
# Step 9600: loss_history = -382.0528564453125
# Step 9700: loss_history = -386.5500183105469
# Step 9800: loss_history = -391.34088134765625
# Step 9900: loss_history = -396.3491516113281
# Step 10000: loss_history = -401.5582275390625
# Step 10100: loss_history = -406.9884948730469
# Step 10200: loss_history = -412.5387878417969
# Step 10300: loss_history = -418.2992858886719
# Step 10400: loss_history = -424.3014221191406
# Step 10500: loss_history = -430.4468688964844
# Step 10600: loss_history = -432.15936279296875
# Step 10700: loss_history = -438.6161193847656
# Step 10800: loss_history = -445.3602600097656
# Step 10900: loss_history = -452.20703125
# Step 11000: loss_history = -454.66131591796875
# Step 11100: loss_history = -461.7178039550781
# Step 11200: loss_history = -464.5926818847656
# Step 11300: loss_history = -472.03216552734375
# Step 11400: loss_history = -475.23193359375
# Step 11500: loss_history = -482.9888610839844
# Step 11600: loss_history = -486.3976745605469
# Step 11700: loss_history = -490.05633544921875
# Step 11800: loss_history = -497.6407470703125
# Step 11900: loss_history = -502.112548828125
# Step 12000: loss_history = -506.1568908691406
# Step 12100: loss_history = -510.3852844238281
# Step 12200: loss_history = -514.696533203125
# Step 12300: loss_history = -519.1651000976562
# Step 12400: loss_history = -523.7000122070312
# Step 12500: loss_history = -528.3617553710938
# Step 12600: loss_history = -532.3982543945312
# Step 12700: loss_history = -533.8924560546875
# Step 12800: loss_history = -538.8051147460938
# Step 12900: loss_history = -539.8001708984375
# Step 13000: loss_history = -544.8558959960938
# Step 13100: loss_history = -546.0889282226562
# Step 13200: loss_history = -551.298828125
# Step 13300: loss_history = -552.62451171875
# Step 13400: loss_history = -558.0369262695312
# Step 13500: loss_history = -559.5502319335938
# Step 13600: loss_history = -561.1334228515625
# Step 13700: loss_history = -565.5518798828125
# Step 13800: loss_history = -568.4987182617188
# Step 13900: loss_history = -570.3164672851562
# Step 14000: loss_history = -572.232666015625
# Step 14100: loss_history = -574.2474975585938
# Step 14200: loss_history = -580.1978149414062
# Step 14300: loss_history = -582.3169555664062
# Step 14400: loss_history = -584.5260620117188
# Step 14500: loss_history = -586.8133544921875
# Step 14600: loss_history = -589.2030029296875
# Step 14700: loss_history = -591.6658325195312
# Step 14800: loss_history = -594.2158813476562
# Step 14900: loss_history = -596.8252563476562
# Step 15000: loss_history = -599.516845703125
# Step 15100: loss_history = -602.2689208984375
# Step 15200: loss_history = -605.1158447265625
# Step 15300: loss_history = -608.0093994140625
# Step 15400: loss_history = -610.992431640625
# Step 15500: loss_history = -614.0302124023438
# Step 15600: loss_history = -617.1736450195312
# Step 15700: loss_history = -620.3658447265625
# Step 15800: loss_history = -623.6434936523438
# Step 15900: loss_history = -627.0289306640625
# Step 16000: loss_history = -626.648193359375
# Step 16100: loss_history = -630.1710815429688
# Step 16200: loss_history = -633.6904907226562
# Step 16300: loss_history = -633.6721801757812
# Step 16400: loss_history = -637.2974853515625
# Step 16500: loss_history = -641.1158447265625
# Step 16600: loss_history = -641.1861572265625
# Step 16700: loss_history = -641.4627685546875
# Step 16800: loss_history = -645.336669921875
# Step 16900: loss_history = -645.7127075195312
# Step 17000: loss_history = -649.74462890625
# Step 17100: loss_history = -650.2095336914062
# Step 17200: loss_history = -650.7487182617188
# Step 17300: loss_history = -654.9304809570312
# Step 17400: loss_history = -655.5410766601562
# Step 17500: loss_history = -656.2359008789062
# Step 17600: loss_history = -657.01513671875
# Step 17700: loss_history = -661.3637084960938
# Step 17800: loss_history = -662.201171875
# Step 17900: loss_history = -663.0982055664062
# Step 18000: loss_history = -664.045166015625
# Step 18100: loss_history = -665.0526733398438
# Step 18200: loss_history = -669.6400756835938
# Step 18300: loss_history = -670.712158203125
# Step 18400: loss_history = -671.8320922851562
# Step 18500: loss_history = -673.0048828125
# Step 18600: loss_history = -674.2273559570312
# Step 18700: loss_history = -675.502197265625
# Step 18800: loss_history = -676.8199462890625
# Step 18900: loss_history = -678.182373046875
# Step 19000: loss_history = -679.6015625
# Step 19100: loss_history = -681.0635375976562
# Step 19200: loss_history = -682.5650024414062
# Step 19300: loss_history = -680.6419067382812
# Step 19400: loss_history = -682.2262573242188
# Step 19500: loss_history = -683.8546752929688
# Step 19600: loss_history = -685.5260620117188
# Step 19700: loss_history = -687.2569580078125
# Step 19800: loss_history = -689.0228881835938
# Step 19900: loss_history = -687.38623046875
# Step 20000: loss_history = -689.214111328125
# Step 20100: loss_history = -691.0958862304688
# Step 20200: loss_history = -693.0454711914062
# Step 20300: loss_history = -693.1300659179688
# Step 20400: loss_history = -693.6213989257812
# Step 20500: loss_history = -695.6651000976562
# Step 20600: loss_history = -694.36083984375
# Step 20700: loss_history = -696.4639892578125
# Step 20800: loss_history = -698.6387329101562
# Step 20900: loss_history = -700.8956298828125
# Step 21000: loss_history = -699.7124633789062
# Step 21100: loss_history = -702.0191040039062
# Step 21200: loss_history = -700.8875122070312
# Step 21300: loss_history = -703.26708984375
# Step 21400: loss_history = -702.2887573242188
# Step 21500: loss_history = -704.7153930664062
# Step 21600: loss_history = -703.7875366210938
# Step 21700: loss_history = -706.2879638671875
# Step 21800: loss_history = -705.4683837890625
# Step 21900: loss_history = -708.0429077148438
# Step 22000: loss_history = -707.2529296875
# Step 22100: loss_history = -709.9223022460938
# Step 22200: loss_history = -709.2332763671875
# Step 22300: loss_history = -711.985595703125
# Step 22400: loss_history = -711.3301391601562
# Step 22500: loss_history = -710.8008422851562
# Step 22600: loss_history = -713.6292724609375
# Step 22700: loss_history = -713.1116333007812
# Step 22800: loss_history = -716.0612182617188
# Step 22900: loss_history = -715.6368408203125
# Step 23000: loss_history = -715.2587890625
# Step 23100: loss_history = -717.9442749023438
# Step 23200: loss_history = -718.019775390625
# Step 23300: loss_history = -717.751708984375
# Step 23400: loss_history = -717.5592041015625
# Step 23500: loss_history = -719.8041381835938
# Step 23600: loss_history = -720.5851440429688
# Step 23700: loss_history = -720.4951782226562
# Step 23800: loss_history = -720.427978515625
# Step 23900: loss_history = -720.4224853515625
# Step 24000: loss_history = -723.685302734375
# Step 24100: loss_history = -723.795166015625
# Step 24200: loss_history = -723.8803100585938
# Step 24300: loss_history = -723.9791870117188
# Step 24400: loss_history = -724.1397094726562
# Step 24500: loss_history = -724.3138427734375
# Step 24600: loss_history = -724.546630859375
# Step 24700: loss_history = -724.78759765625
# Step 24800: loss_history = -725.0878295898438
# Step 24900: loss_history = -725.391357421875
# Step 25000: loss_history = -728.3351440429688
# Step 25100: loss_history = -729.4260864257812
# Step 25200: loss_history = -729.404296875
# Step 25300: loss_history = -730.256103515625
# Step 25400: loss_history = -730.7059326171875
# Step 25500: loss_history = -731.20849609375
# Step 25600: loss_history = -731.7216186523438
# Step 25700: loss_history = -729.5513305664062
# Step 25800: loss_history = -729.562255859375
# Step 25900: loss_history = -730.1561889648438
# Step 26000: loss_history = -730.7883911132812
# Step 26100: loss_history = -731.4374389648438
# Step 26200: loss_history = -732.1244506835938
# Step 26300: loss_history = -732.8282470703125
# Step 26400: loss_history = -733.57080078125
# Step 26500: loss_history = -734.33154296875
# Step 26600: loss_history = -735.1325073242188
# Step 26700: loss_history = -735.953125
# Step 26800: loss_history = -733.5225830078125
# Step 26900: loss_history = -734.3778076171875
# Step 27000: loss_history = -735.2568359375
# Step 27100: loss_history = -736.1703491210938
# Step 27200: loss_history = -737.1099853515625
# Step 27300: loss_history = -738.0858154296875
# Step 27400: loss_history = -735.8012084960938
# Step 27500: loss_history = -736.7950439453125
# Step 27600: loss_history = -737.8218994140625
# Step 27700: loss_history = -738.8806762695312
# Step 27800: loss_history = -738.4002685546875
# Step 27900: loss_history = -737.7952880859375
# Step 28000: loss_history = -738.9083862304688
# Step 28100: loss_history = -740.0550537109375
# Step 28200: loss_history = -739.19677734375
# Step 28300: loss_history = -739.1529541015625
# Step 28400: loss_history = -740.3519897460938
# Step 28500: loss_history = -741.593017578125
# Step 28600: loss_history = -739.59033203125
# Step 28700: loss_history = -740.8389282226562
# Step 28800: loss_history = -742.1316528320312
# Step 28900: loss_history = -740.1998291015625
# Step 29000: loss_history = -741.4986572265625
# Step 29100: loss_history = -742.8450317382812
# Step 29200: loss_history = -740.9717407226562
# Step 29300: loss_history = -742.3250732421875
# Step 29400: loss_history = -743.7265014648438
# Step 29500: loss_history = -741.9030151367188
# Step 29600: loss_history = -743.3115234375
# Step 29700: loss_history = -744.7713623046875
# Step 29800: loss_history = -742.9884033203125
# Step 29900: loss_history = -744.4573974609375
# Step 30000: loss_history = -745.1490478515625
# Step 30100: loss_history = -744.2279663085938
# Step 30200: loss_history = -745.7618408203125
# Step 30300: loss_history = -744.0724487304688
# Step 30400: loss_history = -745.624267578125
# Step 30500: loss_history = -745.5216064453125
# Step 30600: loss_history = -745.5573120117188
# Step 30700: loss_history = -747.1793212890625
# Step 30800: loss_history = -745.55712890625
# Step 30900: loss_history = -747.1964721679688
# Step 31000: loss_history = -745.6137084960938
# Step 31100: loss_history = -747.2681884765625
# Step 31200: loss_history = -745.72314453125
# Step 31300: loss_history = -747.3963623046875
# Step 31400: loss_history = -748.189453125
# Step 31500: loss_history = -747.5723266601562
# Step 31600: loss_history = -749.3233642578125
# Step 31700: loss_history = -747.8010864257812
# Step 31800: loss_history = -749.5659790039062
# Step 31900: loss_history = -748.0703125
# Step 32000: loss_history = -749.8612060546875
# Step 32100: loss_history = -748.3910522460938
# Step 32200: loss_history = -750.1951293945312
# Step 32300: loss_history = -748.746826171875
# Step 32400: loss_history = -750.5822143554688
# Step 32500: loss_history = -749.1541748046875
# Step 32600: loss_history = -751.0018310546875
# Step 32700: loss_history = -749.5921020507812
# Step 32800: loss_history = -751.4743041992188
# Step 32900: loss_history = -750.0806884765625
# Step 33000: loss_history = -751.9762573242188
# Step 33100: loss_history = -750.5970458984375
# Step 33200: loss_history = -752.2138061523438
# Step 33300: loss_history = -751.1660766601562
# Step 33400: loss_history = -749.6714477539062
# Step 33500: loss_history = -751.7589721679688
# Step 33600: loss_history = -750.456787109375
# Step 33700: loss_history = -752.4061889648438
# Step 33800: loss_history = -751.1126098632812
# Step 33900: loss_history = -753.0758056640625
# Step 34000: loss_history = -751.7898559570312
# Step 34100: loss_history = -753.802490234375
# Step 34200: loss_history = -752.5213012695312
# Step 34300: loss_history = -752.0932006835938
# Step 34400: loss_history = -753.2742309570312
# Step 34500: loss_history = -752.0465087890625
# Step 34600: loss_history = -754.0830688476562
# Step 34700: loss_history = -752.8570556640625
# Step 34800: loss_history = -754.9127197265625
# Step 34900: loss_history = -753.6888427734375
# Step 35000: loss_history = -752.5107421875
# Step 35100: loss_history = -754.5781860351562
# Step 35200: loss_history = -753.3992309570312
# Step 35300: loss_history = -755.48876953125
# Step 35400: loss_history = -754.3093872070312
# Step 35500: loss_history = -753.4258422851562
# Step 35600: loss_history = -755.275634765625
# Step 35700: loss_history = -754.1328125
# Step 35800: loss_history = -756.2633056640625
# Step 35900: loss_history = -755.1175537109375
# Step 36000: loss_history = -754.0098876953125
# Step 36100: loss_history = -756.1576538085938
# Step 36200: loss_history = -755.0436401367188
# Step 36300: loss_history = -757.2208251953125
# Step 36400: loss_history = -756.1016235351562
# Step 36500: loss_history = -755.01904296875
# Step 36600: loss_history = -757.2158203125
# Step 36700: loss_history = -756.1250610351562
# Step 36800: loss_history = -755.0693969726562
# Step 36900: loss_history = -757.2595825195312
# Step 37000: loss_history = -756.1973876953125
# Step 37100: loss_history = -758.4510498046875
# Step 37200: loss_history = -757.3787231445312
# Step 37300: loss_history = -756.3400268554688
# Step 37400: loss_history = -758.5906982421875
# Step 37500: loss_history = -757.543212890625
# Step 37600: loss_history = -756.5289916992188
# Step 37700: loss_history = -758.80322265625
# Step 37800: loss_history = -757.7769165039062
# Step 37900: loss_history = -756.7808837890625
# Step 38000: loss_history = -759.0615844726562
# Step 38100: loss_history = -758.0557250976562
# Step 38200: loss_history = -757.080322265625
# Step 38300: loss_history = -759.3843383789062
# Step 38400: loss_history = -758.3963623046875
# Step 38500: loss_history = -757.437744140625
# Step 38600: loss_history = -759.75244140625
# Step 38700: loss_history = -758.7824096679688
# Step 38800: loss_history = -757.839111328125
# Step 38900: loss_history = -760.1832885742188
# Step 39000: loss_history = -759.2259521484375
# Step 39100: loss_history = -758.2973022460938
# Step 39200: loss_history = -760.65771484375
# Step 39300: loss_history = -759.7159423828125
# Step 39400: loss_history = -758.8004760742188
# Step 39500: loss_history = -761.1928100585938
# Step 39600: loss_history = -760.2621459960938
# Step 39700: loss_history = -759.3572998046875
# Step 39800: loss_history = -761.7450561523438
# Step 39900: loss_history = -760.8585815429688
# Step 40000: loss_history = -759.964111328125
# Step 40100: loss_history = -759.0946044921875
# Step 40200: loss_history = -761.5050048828125
# Step 40300: loss_history = -760.6198120117188
# Step 40400: loss_history = -759.7587280273438
# Step 40500: loss_history = -762.1965942382812
# Step 40600: loss_history = -761.3201293945312
# Step 40700: loss_history = -760.4674682617188
# Step 40800: loss_history = -761.99560546875
# Step 40900: loss_history = -762.0680541992188
# Step 41000: loss_history = -761.2218017578125
# Step 41100: loss_history = -760.3978271484375
# Step 41200: loss_history = -762.8688354492188
# Step 41300: loss_history = -762.0283813476562
# Step 41400: loss_history = -761.2098388671875
# Step 41500: loss_history = -761.9659423828125
# Step 41600: loss_history = -762.8815307617188
# Step 41700: loss_history = -762.0675659179688
# Step 41800: loss_history = -761.2743530273438
# Step 41900: loss_history = -763.7905883789062
# Step 42000: loss_history = -762.9808349609375
# Step 42100: loss_history = -762.1903686523438
# Step 42200: loss_history = -761.4202880859375
# Step 42300: loss_history = -763.9386596679688
# Step 42400: loss_history = -763.1511840820312
# Step 42500: loss_history = -762.3826293945312
# Step 42600: loss_history = -761.5375366210938
# Step 42700: loss_history = -764.1701049804688
# Step 42800: loss_history = -763.4036865234375
# Step 42900: loss_history = -762.65625
# Step 43000: loss_history = -763.1203002929688
# Step 43100: loss_history = -764.4713134765625
# Step 43200: loss_history = -763.7242431640625
# Step 43300: loss_history = -762.9949340820312
# Step 43400: loss_history = -763.843505859375
# Step 43500: loss_history = -764.8543090820312
# Step 43600: loss_history = -764.1243896484375
# Step 43700: loss_history = -763.4116821289062
# Step 43800: loss_history = -763.2802124023438
# Step 43900: loss_history = -765.300048828125
# Step 44000: loss_history = -764.5855102539062
# Step 44100: loss_history = -763.8872680664062
# Step 44200: loss_history = -763.2049560546875
# Step 44300: loss_history = -765.82080078125
# Step 44400: loss_history = -765.1201782226562
# Step 44500: loss_history = -764.43505859375
# Step 44600: loss_history = -763.765380859375
# Step 44700: loss_history = -766.4033203125
# Step 44800: loss_history = -765.71533203125
# Step 44900: loss_history = -765.0428466796875
# Step 45000: loss_history = -764.3850708007812
# Step 45100: loss_history = -765.936767578125
# Step 45200: loss_history = -766.3839111328125
# Step 45300: loss_history = -765.7225952148438
# Step 45400: loss_history = -765.0753173828125
# Step 45500: loss_history = -764.4423217773438
# Step 45600: loss_history = -767.1130981445312
# Step 45700: loss_history = -766.4627075195312
# Step 45800: loss_history = -765.82568359375
# Step 45900: loss_history = -765.2018432617188
# Step 46000: loss_history = -765.4388427734375
# Step 46100: loss_history = -767.2752075195312
# Step 46200: loss_history = -766.6475830078125
# Step 46300: loss_history = -766.0325317382812
# Step 46400: loss_history = -765.4301147460938
# Step 46500: loss_history = -767.7349243164062
# Step 46600: loss_history = -767.5306396484375
# Step 46700: loss_history = -766.9232788085938
# Step 46800: loss_history = -766.3285522460938
# Step 46900: loss_history = -765.7459716796875
# Step 47000: loss_history = -768.4871826171875
# Step 47100: loss_history = -767.8869018554688
# Step 47200: loss_history = -767.298583984375
# Step 47300: loss_history = -766.7225952148438
# Step 47400: loss_history = -766.1573486328125
# Step 47500: loss_history = -768.7605590820312
# Step 47600: loss_history = -768.3333740234375
# Step 47700: loss_history = -767.7623291015625
# Step 47800: loss_history = -767.203369140625
# Step 47900: loss_history = -766.6558227539062
# Step 48000: loss_history = -767.3148193359375
# Step 48100: loss_history = -768.877685546875
# Step 48200: loss_history = -768.3229370117188
# Step 48300: loss_history = -767.7794189453125
# Step 48400: loss_history = -767.2466430664062
# Step 48500: loss_history = -766.7243041992188
# Step 48600: loss_history = -769.5093994140625
# Step 48700: loss_history = -768.9697875976562
# Step 48800: loss_history = -768.4404907226562
# Step 48900: loss_history = -767.9217529296875
# Step 49000: loss_history = -767.4130859375
# Step 49100: loss_history = -768.0858764648438
# Step 49200: loss_history = -769.7113037109375
# Step 49300: loss_history = -769.1951904296875
# Step 49400: loss_history = -768.6891479492188
# Step 49500: loss_history = -768.19287109375
# Step 49600: loss_history = -767.7057495117188
# Step 49700: loss_history = -769.7828979492188
# Step 49800: loss_history = -770.0363159179688
# Step 49900: loss_history = -769.5422973632812
# Step 50000: loss_history = -769.0571899414062
# Step 50100: loss_history = -768.5819091796875
# Step 50200: loss_history = -768.1149291992188
# Step 50300: loss_history = -770.0133666992188
# Step 50400: loss_history = -770.4907836914062
# Step 50500: loss_history = -770.0162963867188
# Step 50600: loss_history = -769.551025390625
# Step 50700: loss_history = -769.093994140625
# Step 50800: loss_history = -768.6459350585938
# Step 50900: loss_history = -768.4791259765625
# Step 51000: loss_history = -771.0625
# Step 51100: loss_history = -770.6063842773438
# Step 51200: loss_history = -770.1586303710938
# Step 51300: loss_history = -769.7191162109375
# Step 51400: loss_history = -769.2879638671875
# Step 51500: loss_history = -768.8649291992188
# Step 51600: loss_history = -771.5178833007812
# Step 51700: loss_history = -771.321044921875
# Step 51800: loss_history = -770.8900756835938
# Step 51900: loss_history = -770.466796875
# Step 52000: loss_history = -770.0508422851562
# Step 52100: loss_history = -769.6429443359375
# Step 52200: loss_history = -769.2418823242188
# Step 52300: loss_history = -772.150390625
# Step 52400: loss_history = -771.73486328125
# Step 52500: loss_history = -771.3267822265625
# Step 52600: loss_history = -770.9259033203125
# Step 52700: loss_history = -770.5324096679688
# Step 52800: loss_history = -770.1461181640625
# Step 52900: loss_history = -769.7666015625
# Step 53000: loss_history = -771.3184814453125
# Step 53100: loss_history = -772.31396484375
# Step 53200: loss_history = -771.9268188476562
# Step 53300: loss_history = -771.546630859375
# Step 53400: loss_history = -771.1727905273438
# Step 53500: loss_history = -770.8055419921875
# Step 53600: loss_history = -770.4446411132812
# Step 53700: loss_history = -770.0899047851562
# Step 53800: loss_history = -773.0409545898438
# Step 53900: loss_history = -772.6727294921875
# Step 54000: loss_history = -772.310546875
# Step 54100: loss_history = -771.9545288085938
# Step 54200: loss_history = -771.6048583984375
# Step 54300: loss_history = -771.260986328125
# Step 54400: loss_history = -770.9232788085938
# Step 54500: loss_history = -770.5912475585938
# Step 54600: loss_history = -772.8028564453125
# Step 54700: loss_history = -773.2283935546875
# Step 54800: loss_history = -772.8892822265625
# Step 54900: loss_history = -772.5556640625
# Step 55000: loss_history = -772.227783203125
# Step 55100: loss_history = -771.9056396484375
# Step 55200: loss_history = -771.5887451171875
# Step 55300: loss_history = -771.2772827148438
# Step 55400: loss_history = -770.9725341796875
# Step 55500: loss_history = -773.9639282226562
# Step 55600: loss_history = -773.6460571289062
# Step 55700: loss_history = -773.3333129882812
# Step 55800: loss_history = -773.0263061523438
# Step 55900: loss_history = -772.724365234375
# Step 56000: loss_history = -772.4274291992188
# Step 56100: loss_history = -772.1358642578125
# Step 56200: loss_history = -771.8492431640625
# Step 56300: loss_history = -771.5674438476562
# Step 56400: loss_history = -773.0899047851562
# Step 56500: loss_history = -774.3042602539062
# Step 56600: loss_history = -774.0151977539062
# Step 56700: loss_history = -773.7310791015625
# Step 56800: loss_history = -773.4513549804688
# Step 56900: loss_history = -773.1768188476562
# Step 57000: loss_history = -772.9074096679688
# Step 57100: loss_history = -772.6426391601562
# Step 57200: loss_history = -772.38134765625
# Step 57300: loss_history = -772.1259155273438
# Step 57400: loss_history = -772.7431030273438
# Step 57500: loss_history = -774.90771484375
# Step 57600: loss_history = -772.9276123046875
# Step 57700: loss_history = -772.6943359375
# Step 57800: loss_history = -772.4761352539062
# Step 57900: loss_history = -772.2445678710938
# Step 58000: loss_history = -774.797607421875
# Step 58100: loss_history = -775.0496215820312
# Step 58200: loss_history = -774.803466796875
# Step 58300: loss_history = -774.5625610351562
# Step 58400: loss_history = -774.3260498046875
# Step 58500: loss_history = -774.0933227539062
# Step 58600: loss_history = -773.8648681640625
# Step 58700: loss_history = -773.6403198242188
# Step 58800: loss_history = -773.4197998046875
# Step 58900: loss_history = -773.2027587890625
# Step 59000: loss_history = -772.9894409179688
# Step 59100: loss_history = -772.7799682617188
# Step 59200: loss_history = -775.66015625
# Step 59300: loss_history = -775.6448364257812
# Step 59400: loss_history = -775.4299926757812
# Step 59500: loss_history = -775.2188720703125
# Step 59600: loss_history = -775.01171875
# Step 59700: loss_history = -774.8081665039062
# Step 59800: loss_history = -774.6082763671875
# Step 59900: loss_history = -774.4113159179688
# Step 60000: loss_history = -774.2183837890625
# Step 60100: loss_history = -774.0291137695312
# Step 60200: loss_history = -773.842529296875
# Step 60300: loss_history = -773.6603393554688
# Step 60400: loss_history = -773.4801635742188
# Step 60500: loss_history = -774.607421875
# Step 60600: loss_history = -776.4029541015625
# Step 60700: loss_history = -776.2192993164062
# Step 60800: loss_history = -776.038330078125
# Step 60900: loss_history = -775.861328125
# Step 61000: loss_history = -775.6870727539062
# Step 61100: loss_history = -775.516357421875
# Step 61200: loss_history = -775.348876953125
# Step 61300: loss_history = -775.1842651367188
# Step 61400: loss_history = -775.0225830078125
# Step 61500: loss_history = -774.8640747070312
# Step 61600: loss_history = -774.70849609375
# Step 61700: loss_history = -774.5557250976562
# Step 61800: loss_history = -774.4057006835938
# Step 61900: loss_history = -774.2581787109375
# Step 62000: loss_history = -774.1132202148438
# Step 62100: loss_history = -775.5188598632812
# Step 62200: loss_history = -777.1034545898438
# Step 62300: loss_history = -776.9549560546875
# Step 62400: loss_history = -776.8091430664062
# Step 62500: loss_history = -776.666015625
# Step 62600: loss_history = -776.5253295898438
# Step 62700: loss_history = -776.3871459960938
# Step 62800: loss_history = -776.25146484375
# Step 62900: loss_history = -776.1177368164062
# Step 63000: loss_history = -775.9869995117188
# Step 63100: loss_history = -775.8582763671875
# Step 63200: loss_history = -775.7319946289062
# Step 63300: loss_history = -775.607666015625
# Step 63400: loss_history = -775.4849853515625
# Step 63500: loss_history = -775.3646850585938
# Step 63600: loss_history = -775.2461547851562
# Step 63700: loss_history = -775.129638671875
# Step 63800: loss_history = -775.0161743164062
# Step 63900: loss_history = -774.9035034179688
# Step 64000: loss_history = -775.3416137695312
# Step 64100: loss_history = -777.196044921875
# Step 64200: loss_history = -777.85400390625
# Step 64300: loss_history = -777.7413940429688
# Step 64400: loss_history = -777.6311645507812
# Step 64500: loss_history = -777.52294921875
# Step 64600: loss_history = -777.416259765625
# Step 64700: loss_history = -777.3125
# Step 64800: loss_history = -777.2096557617188
# Step 64900: loss_history = -777.109375
# Step 65000: loss_history = -777.0108032226562
# Step 65100: loss_history = -776.9139404296875
# Step 65200: loss_history = -776.8187255859375
# Step 65300: loss_history = -776.7257690429688
# Step 65400: loss_history = -776.6336059570312
# Step 65500: loss_history = -776.544189453125
# Step 65600: loss_history = -776.456298828125
# Step 65700: loss_history = -776.3699340820312
# Step 65800: loss_history = -776.2852172851562
# Step 65900: loss_history = -776.202880859375
# Step 66000: loss_history = -776.1214599609375
# Step 66100: loss_history = -776.0425415039062
# Step 66200: loss_history = -775.9647827148438
# Step 66300: loss_history = -775.8887939453125
# Step 66400: loss_history = -775.814453125
# Step 66500: loss_history = -775.7407836914062
# Step 66600: loss_history = -776.8107299804688
# Step 66700: loss_history = -778.1007690429688
# Step 66800: loss_history = -778.828125
# Step 66900: loss_history = -778.7557983398438
# Step 67000: loss_history = -778.6851806640625
# Step 67100: loss_history = -778.6165161132812
# Step 67200: loss_history = -778.5492553710938
# Step 67300: loss_history = -778.48388671875
# Step 67400: loss_history = -778.4197998046875
# Step 67500: loss_history = -778.357666015625
# Step 67600: loss_history = -778.2969360351562
# Step 67700: loss_history = -778.2380981445312
# Step 67800: loss_history = -778.1806030273438
# Step 67900: loss_history = -778.1243286132812
# Step 68000: loss_history = -778.0697631835938
# Step 68100: loss_history = -778.0170288085938
# Step 68200: loss_history = -777.9654541015625
# Step 68300: loss_history = -777.9158325195312
# Step 68400: loss_history = -777.8682861328125
# Step 68500: loss_history = -777.8208618164062
# Step 68600: loss_history = -777.7760620117188
# Step 68700: loss_history = -777.7320556640625
# Step 68800: loss_history = -777.6901245117188
# Step 68900: loss_history = -777.6493530273438
# Step 69000: loss_history = -777.6098022460938
# Step 69100: loss_history = -777.5730590820312
# Step 69200: loss_history = -777.5361938476562
# Step 69300: loss_history = -777.5018310546875
# Step 69400: loss_history = -777.4674682617188
# Step 69500: loss_history = -777.4363403320312
# Step 69600: loss_history = -777.4052124023438
# Step 69700: loss_history = -777.3760375976562
# Step 69800: loss_history = -777.3477783203125
# Step 69900: loss_history = -777.3214111328125
# Step 70000: loss_history = -777.2968139648438
# Step 70100: loss_history = -777.2721557617188
# Step 70200: loss_history = -777.2501220703125
# Step 70300: loss_history = -777.228271484375
# Step 70400: loss_history = -777.2085571289062
# Step 70500: loss_history = -777.1910400390625
# Step 70600: loss_history = -777.1729125976562
# Step 70700: loss_history = -777.1571044921875
# Step 70800: loss_history = -777.1429443359375
# Step 70900: loss_history = -777.129150390625
# Step 71000: loss_history = -777.0067749023438
# Step 71100: loss_history = -777.668212890625
# Step 71200: loss_history = -778.1024780273438
# Step 71300: loss_history = -778.5907592773438
# Step 71400: loss_history = -779.041259765625
# Step 71500: loss_history = -779.4976196289062
# Step 71600: loss_history = -779.9618530273438
# Step 71700: loss_history = -780.348876953125
# Step 71800: loss_history = -780.39404296875
# Step 71900: loss_history = -780.3916015625
# Step 72000: loss_history = -780.3916015625
# Step 72100: loss_history = -780.392822265625
# Step 72200: loss_history = -780.3952026367188
# Step 72300: loss_history = -780.3974609375
# Step 72400: loss_history = -780.4017944335938
# Step 72500: loss_history = -780.4077758789062
# Step 72600: loss_history = -780.41552734375
# Step 72700: loss_history = -780.4244384765625
# Step 72800: loss_history = -780.4349365234375
# Step 72900: loss_history = -780.4466552734375
# Step 73000: loss_history = -780.4579467773438
# Step 73100: loss_history = -780.471435546875
# Step 73200: loss_history = -780.4862060546875
# Step 73300: loss_history = -780.50244140625
# Step 73400: loss_history = -780.5198364257812
# Step 73500: loss_history = -780.5386962890625
# Step 73600: loss_history = -780.5589599609375
# Step 73700: loss_history = -780.5803833007812
# Step 73800: loss_history = -780.6029052734375
# Step 73900: loss_history = -780.6270751953125
# Step 74000: loss_history = -780.6525268554688
# Step 74100: loss_history = -780.678955078125
# Step 74200: loss_history = -780.7064208984375
# Step 74300: loss_history = -780.7351684570312
# Step 74400: loss_history = -780.7649536132812
# Step 74500: loss_history = -780.79638671875
# Step 74600: loss_history = -780.8291625976562
# Step 74700: loss_history = -780.8629150390625
# Step 74800: loss_history = -780.8975830078125
# Step 74900: loss_history = -780.933349609375
# Step 75000: loss_history = -780.9705200195312
# Step 75100: loss_history = -781.0086059570312
# Step 75200: loss_history = -781.0477294921875
# Step 75300: loss_history = -781.0883178710938
# Step 75400: loss_history = -781.1310424804688
# Step 75500: loss_history = -781.1751098632812
# Step 75600: loss_history = -781.2194213867188
# Step 75700: loss_history = -781.264892578125
# Step 75800: loss_history = -781.3114624023438
# Step 75900: loss_history = -781.3589477539062
# Step 76000: loss_history = -781.4080200195312
# Step 76100: loss_history = -781.4595336914062
# Step 76200: loss_history = -781.511474609375
# Step 76300: loss_history = -781.564208984375
# Step 76400: loss_history = -781.6173095703125
# Step 76500: loss_history = -781.560791015625
# Step 76600: loss_history = -781.0789184570312
# Step 76700: loss_history = -780.7689819335938
# Step 76800: loss_history = -780.382080078125
# Step 76900: loss_history = -780.0403442382812
# Step 77000: loss_history = -779.5266723632812
# Step 77100: loss_history = -779.1514892578125
# Step 77200: loss_history = -778.69970703125
# Step 77300: loss_history = -778.7924194335938
# Step 77400: loss_history = -778.8562622070312
# Step 77500: loss_history = -778.9209594726562
# Step 77600: loss_history = -778.9862060546875
# Step 77700: loss_history = -779.0527954101562
# Step 77800: loss_history = -779.12109375
# Step 77900: loss_history = -779.188720703125
# Step 78000: loss_history = -779.2579345703125
# Step 78100: loss_history = -779.32958984375
# Step 78200: loss_history = -779.4015502929688
# Step 78300: loss_history = -779.475341796875
# Step 78400: loss_history = -779.5494384765625
# Step 78500: loss_history = -779.6239013671875
# Step 78600: loss_history = -779.701416015625
# Step 78700: loss_history = -779.7789916992188
# Step 78800: loss_history = -779.8587646484375
# Step 78900: loss_history = -779.9390258789062
# Step 79000: loss_history = -780.0193481445312
# Step 79100: loss_history = -780.1024169921875
# Step 79200: loss_history = -780.1859741210938
# Step 79300: loss_history = -780.271728515625
# Step 79400: loss_history = -780.3561401367188
# Step 79500: loss_history = -780.4439697265625
# Step 79600: loss_history = -780.5321655273438
# Step 79700: loss_history = -780.6221313476562
# Step 79800: loss_history = -780.7113647460938
# Step 79900: loss_history = -780.8030395507812
# Step 80000: loss_history = -780.8955078125
# Step 80100: loss_history = -780.9900512695312
# Step 80200: loss_history = -781.0836181640625
# Step 80300: loss_history = -781.1800537109375
# Step 80400: loss_history = -781.2774047851562
# Step 80500: loss_history = -781.3755493164062
# Step 80600: loss_history = -781.4744262695312
# Step 80700: loss_history = -781.5747680664062
# Step 80800: loss_history = -781.6768188476562
# Step 80900: loss_history = -781.7791748046875
# Step 81000: loss_history = -781.883056640625
# Step 81100: loss_history = -781.9881591796875
# Step 81200: loss_history = -782.0942993164062
# Step 81300: loss_history = -782.2017211914062
# Step 81400: loss_history = -782.310302734375
# Step 81500: loss_history = -782.4200439453125
# Step 81600: loss_history = -782.5303344726562
# Step 81700: loss_history = -782.64208984375
# Step 81800: loss_history = -782.7557983398438
# Step 81900: loss_history = -782.8694458007812
# Step 82000: loss_history = -781.8892211914062
# Step 82100: loss_history = -780.874267578125
# Step 82200: loss_history = -779.849853515625
# Step 82300: loss_history = -779.9627075195312
# Step 82400: loss_history = -780.0765380859375
# Step 82500: loss_history = -780.1923217773438
# Step 82600: loss_history = -780.3082275390625
# Step 82700: loss_history = -780.4251708984375
# Step 82800: loss_history = -780.5438232421875
# Step 82900: loss_history = -780.6632080078125
# Step 83000: loss_history = -780.7842407226562
# Step 83100: loss_history = -780.90576171875
# Step 83200: loss_history = -781.0289306640625
# Step 83300: loss_history = -781.153564453125
# Step 83400: loss_history = -781.2791137695312
# Step 83500: loss_history = -781.4052124023438
# Step 83600: loss_history = -781.5328369140625
# Step 83700: loss_history = -781.6617431640625
# Step 83800: loss_history = -781.7921752929688
# Step 83900: loss_history = -781.92333984375
# Step 84000: loss_history = -782.0554809570312
# Step 84100: loss_history = -782.1891479492188
# Step 84200: loss_history = -782.3236694335938
# Step 84300: loss_history = -782.4597778320312
# Step 84400: loss_history = -782.5969848632812
# Step 84500: loss_history = -782.7352294921875
# Step 84600: loss_history = -782.8746337890625
# Step 84700: loss_history = -783.0150756835938
# Step 84800: loss_history = -783.1572875976562
# Step 84900: loss_history = -783.3001098632812
# Step 85000: loss_history = -783.4447631835938
# Step 85100: loss_history = -782.7432861328125
# Step 85200: loss_history = -781.2691040039062
# Step 85300: loss_history = -780.5054931640625
# Step 85400: loss_history = -780.647216796875
# Step 85500: loss_history = -780.7899169921875
# Step 85600: loss_history = -782.5587158203125
# Step 85700: loss_history = -782.702392578125
# Step 85800: loss_history = -782.873046875
# Step 85900: loss_history = -783.0259399414062
# Step 86000: loss_history = -783.1737060546875
# Step 86100: loss_history = -783.3304443359375
# Step 86200: loss_history = -783.4843139648438
# Step 86300: loss_history = -783.6405029296875
# Step 86400: loss_history = -783.3978881835938
# Step 86500: loss_history = -781.7946166992188
# Step 86600: loss_history = -780.7376708984375
# Step 86700: loss_history = -780.8897094726562
# Step 86800: loss_history = -781.042724609375
# Step 86900: loss_history = -781.1984252929688
# Step 87000: loss_history = -781.3536376953125
# Step 87100: loss_history = -781.5118408203125
# Step 87200: loss_history = -781.6695556640625
# Step 87300: loss_history = -781.8292846679688
# Step 87400: loss_history = -781.9903564453125
# Step 87500: loss_history = -782.15283203125
# Step 87600: loss_history = -782.3162231445312
# Step 87700: loss_history = -782.4808959960938
# Step 87800: loss_history = -782.647216796875
# Step 87900: loss_history = -781.0418701171875
# Step 88000: loss_history = -781.2791748046875
# Step 88100: loss_history = -781.4378662109375
# Step 88200: loss_history = -781.6046142578125
# Step 88300: loss_history = -781.7763061523438
# Step 88400: loss_history = -781.9417724609375
# Step 88500: loss_history = -782.11328125
# Step 88600: loss_history = -782.2838745117188
# Step 88700: loss_history = -782.455810546875
# Step 88800: loss_history = -782.6295166015625
# Step 88900: loss_history = -782.8041381835938
# Step 89000: loss_history = -782.2337646484375
# Step 89100: loss_history = -781.462890625
# Step 89200: loss_history = -781.6113891601562
# Step 89300: loss_history = -781.8004150390625
# Step 89400: loss_history = -781.9765014648438
# Step 89500: loss_history = -782.152587890625
# Step 89600: loss_history = -782.333251953125
# Step 89700: loss_history = -782.5121459960938
# Step 89800: loss_history = -782.6936645507812
# Step 89900: loss_history = -782.876220703125
# Step 90000: loss_history = -783.0602416992188
# Step 90100: loss_history = -783.2457885742188
# Step 90200: loss_history = -783.431884765625
# Step 90300: loss_history = -783.6202392578125
# Step 90400: loss_history = -783.809814453125
# Step 90500: loss_history = -784.00048828125
# Step 90600: loss_history = -784.1926879882812
# Step 90700: loss_history = -784.3862915039062
# Step 90800: loss_history = -784.1143798828125
# Step 90900: loss_history = -782.0474243164062
# Step 91000: loss_history = -781.5900268554688
# Step 91100: loss_history = -781.7781982421875
# Step 91200: loss_history = -781.9683227539062
# Step 91300: loss_history = -782.1585083007812
# Step 91400: loss_history = -782.3506469726562
# Step 91500: loss_history = -782.5446166992188
# Step 91600: loss_history = -782.7390747070312
# Step 91700: loss_history = -782.9356079101562
# Step 91800: loss_history = -783.1336059570312
# Step 91900: loss_history = -783.3324584960938
# Step 92000: loss_history = -783.5335083007812
# Step 92100: loss_history = -783.7356567382812
# Step 92200: loss_history = -783.9386596679688
# Step 92300: loss_history = -784.1435546875
# Step 92400: loss_history = -784.3496704101562
# Step 92500: loss_history = -784.5574340820312
# Step 92600: loss_history = -784.7665405273438
# Step 92700: loss_history = -783.4414672851562
# Step 92800: loss_history = -781.8076171875
# Step 92900: loss_history = -782.0089111328125
# Step 93000: loss_history = -782.2125244140625
# Step 93100: loss_history = -782.41650390625
# Step 93200: loss_history = -782.623046875
# Step 93300: loss_history = -782.8299560546875
# Step 93400: loss_history = -783.0386962890625
# Step 93500: loss_history = -783.2489624023438
# Step 93600: loss_history = -783.4605102539062
# Step 93700: loss_history = -783.6734008789062
# Step 93800: loss_history = -783.8878784179688
# Step 93900: loss_history = -784.1036376953125
# Step 94000: loss_history = -784.3211059570312
# Step 94100: loss_history = -784.5398559570312
# Step 94200: loss_history = -784.760498046875
# Step 94300: loss_history = -784.98193359375
# Step 94400: loss_history = -784.1643676757812
# Step 94500: loss_history = -782.0516357421875
# Step 94600: loss_history = -782.265625
# Step 94700: loss_history = -782.4819946289062
# Step 94800: loss_history = -782.6982421875
# Step 94900: loss_history = -782.9161376953125
# Step 95000: loss_history = -783.1359252929688
# Step 95100: loss_history = -783.357421875
# Step 95200: loss_history = -783.5801391601562
# Step 95300: loss_history = -783.8043823242188
# Step 95400: loss_history = -784.0301513671875
# Step 95500: loss_history = -784.257568359375
# Step 95600: loss_history = -784.4864501953125
# Step 95700: loss_history = -784.7169799804688
# Step 95800: loss_history = -784.948974609375
# Step 95900: loss_history = -785.1824951171875
# Step 96000: loss_history = -784.7609252929688
# Step 96100: loss_history = -782.1655883789062
# Step 96200: loss_history = -782.499267578125
# Step 96300: loss_history = -782.7255859375
# Step 96400: loss_history = -782.9527587890625
# Step 96500: loss_history = -783.1819458007812
# Step 96600: loss_history = -783.4129028320312
# Step 96700: loss_history = -783.6450805664062
# Step 96800: loss_history = -783.8792724609375
# Step 96900: loss_history = -784.114990234375
# Step 97000: loss_history = -784.3521118164062
# Step 97100: loss_history = -784.5913696289062
# Step 97200: loss_history = -784.8316040039062
# Step 97300: loss_history = -785.07373046875
# Step 97400: loss_history = -785.3173828125
# Step 97500: loss_history = -785.5628662109375
# Step 97600: loss_history = -783.104736328125
# Step 97700: loss_history = -782.6661987304688
# Step 97800: loss_history = -782.9012451171875
# Step 97900: loss_history = -783.1388549804688
# Step 98000: loss_history = -783.378173828125
# Step 98100: loss_history = -783.6195068359375
# Step 98200: loss_history = -783.86181640625
# Step 98300: loss_history = -784.1051635742188
# Step 98400: loss_history = -784.3509521484375
# Step 98500: loss_history = -784.5978393554688
# Step 98600: loss_history = -784.8464965820312
# Step 98700: loss_history = -785.0966186523438
# Step 98800: loss_history = -785.348388671875
# Step 98900: loss_history = -785.6016235351562
# Step 99000: loss_history = -785.0421142578125
# Step 99100: loss_history = -782.72265625
# Step 99200: loss_history = -782.9666748046875
# Step 99300: loss_history = -783.2118530273438
# Step 99400: loss_history = -783.4579467773438
# Step 99500: loss_history = -783.70654296875
# Step 99600: loss_history = -783.9560546875
# Step 99700: loss_history = -784.2080078125
# Step 99800: loss_history = -784.46142578125
# Step 99900: loss_history = -784.7159423828125
# Step 100000: loss_history = -784.9728393554688
# Step 100100: loss_history = -785.2307739257812
# Step 100200: loss_history = -785.4909057617188
# Step 100300: loss_history = -785.75244140625
# Step 100400: loss_history = -785.5274658203125
# Step 100500: loss_history = -782.8900146484375
# Step 100600: loss_history = -783.1421508789062
# Step 100700: loss_history = -783.3955078125
# Step 100800: loss_history = -783.6500854492188
# Step 100900: loss_history = -783.9063720703125
# Step 101000: loss_history = -784.1651611328125
# Step 101100: loss_history = -784.4248046875
# Step 101200: loss_history = -784.686279296875
# Step 101300: loss_history = -784.9493408203125
# Step 101400: loss_history = -785.2147827148438
# Step 101500: loss_history = -785.4814453125
# Step 101600: loss_history = -785.7504272460938
# Step 101700: loss_history = -786.0206298828125
# Step 101800: loss_history = -784.5945434570312
# Step 101900: loss_history = -783.1647338867188
# Step 102000: loss_history = -783.424072265625
# Step 102100: loss_history = -783.6857299804688
# Step 102200: loss_history = -783.94970703125
# Step 102300: loss_history = -784.2142944335938
# Step 102400: loss_history = -784.4811401367188
# Step 102500: loss_history = -784.7499389648438
# Step 102600: loss_history = -785.0199584960938
# Step 102700: loss_history = -785.2922973632812
# Step 102800: loss_history = -785.5660400390625
# Step 102900: loss_history = -785.841552734375
# Step 103000: loss_history = -786.119140625
# Step 103100: loss_history = -785.438720703125
# Step 103200: loss_history = -783.2803955078125
# ...
# Step 469600: loss_history = -792.2820434570312
# Step 469700: loss_history = -792.7761840820312
# Step 469800: loss_history = -793.2744140625
# Step 469900: loss_history = -790.14794921875
# Step 470000: loss_history = -790.6238403320312
# Step 470100: loss_history = -791.10546875
# Step 470200: loss_history = -791.5897827148438
# Step 470300: loss_history = -792.0783081054688
# Step 470400: loss_history = -792.57080078125
# Step 470500: loss_history = -793.0670776367188
# Step 470600: loss_history = -790.5167236328125
# Step 470700: loss_history = -790.4262084960938
# Step 470800: loss_history = -790.9052124023438
# Step 470900: loss_history = -791.3883056640625
# Step 471000: loss_history = -791.8750610351562
# Step 471100: loss_history = -792.3658447265625
# Step 471200: loss_history = -792.8606567382812
# Step 471300: loss_history = -792.9475708007812
# Step 471400: loss_history = -790.2293090820312
# Step 471500: loss_history = -790.7061157226562
# Step 471600: loss_history = -791.1875
# Step 471700: loss_history = -791.6728515625
# Step 471800: loss_history = -792.1624755859375
# Step 471900: loss_history = -792.6552734375
# Step 472000: loss_history = -793.1527709960938
# Step 472100: loss_history = -790.0321044921875
# Step 472200: loss_history = -790.50830078125
# Step 472300: loss_history = -790.9886474609375
# Step 472400: loss_history = -791.4716796875
# Step 472500: loss_history = -790.1066284179688
# Step 472600: loss_history = -790.6106567382812
# Step 472700: loss_history = -791.1011962890625
# Step 472800: loss_history = -791.5885620117188
# Step 472900: loss_history = -792.0780029296875
# Step 473000: loss_history = -792.5709228515625
# Step 473100: loss_history = -793.0675048828125
# Step 473200: loss_history = -790.5604248046875
# Step 473300: loss_history = -790.4269409179688
# Step 473400: loss_history = -790.9063110351562
# Step 473500: loss_history = -791.3895263671875
# Step 473600: loss_history = -791.876220703125
# Step 473700: loss_history = -792.3671264648438
# Step 473800: loss_history = -792.8623046875
# Step 473900: loss_history = -792.9765625
# Step 474000: loss_history = -790.2310180664062
# Step 474100: loss_history = -790.7081298828125
# Step 474200: loss_history = -791.1895751953125
# Step 474300: loss_history = -791.6753540039062
# Step 474400: loss_history = -792.1650390625
# Step 474500: loss_history = -792.6580810546875
# Step 474600: loss_history = -793.155517578125
# Step 474700: loss_history = -790.0349731445312
# Step 474800: loss_history = -790.5112915039062
# Step 474900: loss_history = -790.99169921875
# Step 475000: loss_history = -791.47509765625
# Step 475100: loss_history = -791.9635009765625
# Step 475200: loss_history = -792.4550170898438
# Step 475300: loss_history = -792.9505004882812
# Step 475400: loss_history = -791.9718627929688
# Step 475500: loss_history = -790.31494140625
# Step 475600: loss_history = -790.7946166992188
# Step 475700: loss_history = -791.2765502929688
# Step 475800: loss_history = -791.7620239257812
# Step 475900: loss_history = -792.252685546875
# Step 476000: loss_history = -792.7464599609375
# Step 476100: loss_history = -793.2446899414062
# Step 476200: loss_history = -790.12109375
# Step 476300: loss_history = -790.5965576171875
# Step 476400: loss_history = -791.0783081054688
# Step 476500: loss_history = -791.5625
# Step 476600: loss_history = -792.0510864257812
# Step 476700: loss_history = -792.5433349609375
# Step 476800: loss_history = -793.0399169921875
# Step 476900: loss_history = -790.9536743164062
# Step 477000: loss_history = -790.4014282226562
# Step 477100: loss_history = -790.8809204101562
# Step 477200: loss_history = -791.3639526367188
# Step 477300: loss_history = -791.8502807617188
# Step 477400: loss_history = -792.3412475585938
# Step 477500: loss_history = -792.8361206054688
# Step 477600: loss_history = -793.3350830078125
# Step 477700: loss_history = -790.207275390625
# Step 477800: loss_history = -790.6839599609375
# Step 477900: loss_history = -791.16552734375
# Step 478000: loss_history = -791.65087890625
# Step 478100: loss_history = -792.1397705078125
# Step 478200: loss_history = -792.63330078125
# Step 478300: loss_history = -793.1304931640625
# Step 478400: loss_history = -789.9209594726562
# Step 478500: loss_history = -790.4888305664062
# Step 478600: loss_history = -790.9678955078125
# Step 478700: loss_history = -791.4523315429688
# Step 478800: loss_history = -791.939697265625
# Step 478900: loss_history = -792.430908203125
# Step 479000: loss_history = -792.9269409179688
# Step 479100: loss_history = -792.3152465820312
# Step 479200: loss_history = -790.2943725585938
# Step 479300: loss_history = -790.772216796875
# Step 479400: loss_history = -791.2538452148438
# Step 479500: loss_history = -791.7404174804688
# Step 479600: loss_history = -792.2303466796875
# Step 479700: loss_history = -792.7243041992188
# Step 479800: loss_history = -793.2225952148438
# Step 479900: loss_history = -790.099365234375
# Step 480000: loss_history = -790.5770874023438
# Step 480100: loss_history = -791.0574340820312
# Step 480200: loss_history = -791.5416259765625
# Step 480300: loss_history = -792.0303955078125
# Step 480400: loss_history = -792.5228271484375
# Step 480500: loss_history = -793.0194091796875
# Step 480600: loss_history = -791.2600708007812
# Step 480700: loss_history = -790.3817749023438
# Step 480800: loss_history = -790.8615112304688
# Step 480900: loss_history = -791.3442993164062
# Step 481000: loss_history = -791.8311157226562
# Step 481100: loss_history = -792.3221435546875
# Step 481200: loss_history = -792.8170166015625
# Step 481300: loss_history = -793.3160400390625
# Step 481400: loss_history = -790.1888427734375
# Step 481500: loss_history = -790.6661987304688
# Step 481600: loss_history = -791.1478271484375
# Step 481700: loss_history = -791.6329956054688
# Step 481800: loss_history = -792.1222534179688
# Step 481900: loss_history = -792.61572265625
# Step 482000: loss_history = -793.113037109375
# Step 482100: loss_history = -790.1857299804688
# Step 482200: loss_history = -790.47216796875
# Step 482300: loss_history = -790.9517822265625
# Step 482400: loss_history = -791.4357299804688
# Step 482500: loss_history = -791.923828125
# Step 482600: loss_history = -792.4151611328125
# Step 482700: loss_history = -792.9108276367188
# Step 482800: loss_history = -792.5669555664062
# Step 482900: loss_history = -790.2789306640625
# Step 483000: loss_history = -790.7569580078125
# Step 483100: loss_history = -791.2390747070312
# Step 483200: loss_history = -791.7255249023438
# Step 483300: loss_history = -792.2158203125
# Step 483400: loss_history = -792.7097778320312
# Step 483500: loss_history = -793.2080078125
# Step 483600: loss_history = -790.0860595703125
# Step 483700: loss_history = -790.563232421875
# Step 483800: loss_history = -791.0441284179688
# Step 483900: loss_history = -791.528076171875
# Step 484000: loss_history = -792.0170288085938
# Step 484100: loss_history = -792.5096435546875
# Step 484200: loss_history = -793.0062255859375
# Step 484300: loss_history = -791.4745483398438
# Step 484400: loss_history = -790.3699340820312
# Step 484500: loss_history = -790.84912109375
# Step 484600: loss_history = -791.33251953125
# Step 484700: loss_history = -791.8190307617188
# Step 484800: loss_history = -792.3101806640625
# Step 484900: loss_history = -792.8053588867188
# Step 485000: loss_history = -793.30419921875
# Step 485100: loss_history = -790.1782836914062
# Step 485200: loss_history = -790.6553344726562
# Step 485300: loss_history = -791.136962890625
# Step 485400: loss_history = -791.6227416992188
# Step 485500: loss_history = -792.1117553710938
# Step 485600: loss_history = -792.6054077148438
# Step 485700: loss_history = -793.1028442382812
# Step 485800: loss_history = -790.3689575195312
# Step 485900: loss_history = -790.4632568359375
# Step 486000: loss_history = -790.9425659179688
# Step 486100: loss_history = -791.4271240234375
# Step 486200: loss_history = -791.914794921875
# Step 486300: loss_history = -792.40625
# Step 486400: loss_history = -792.9024658203125
# Step 486500: loss_history = -792.7244873046875
# Step 486600: loss_history = -790.27099609375
# Step 486700: loss_history = -790.749755859375
# Step 486800: loss_history = -791.2317504882812
# Step 486900: loss_history = -791.7186279296875
# Step 487000: loss_history = -792.2086791992188
# Step 487100: loss_history = -792.70263671875
# Step 487200: loss_history = -793.2010498046875
# Step 487300: loss_history = -790.0797119140625
# Step 487400: loss_history = -790.5576171875
# Step 487500: loss_history = -791.0382080078125
# Step 487600: loss_history = -791.5223999023438
# Step 487700: loss_history = -792.0115356445312
# Step 487800: loss_history = -792.5040283203125
# Step 487900: loss_history = -793.000732421875
# Step 488000: loss_history = -791.6021728515625
# Step 488100: loss_history = -790.3651733398438
# Step 488200: loss_history = -790.8453369140625
# Step 488300: loss_history = -791.328369140625
# Step 488400: loss_history = -791.8148193359375
# Step 488500: loss_history = -792.306396484375
# Step 488600: loss_history = -792.801513671875
# Step 488700: loss_history = -793.3006591796875
# Step 488800: loss_history = -790.1751098632812
# Step 488900: loss_history = -790.65234375
# Step 489000: loss_history = -791.134765625
# Step 489100: loss_history = -791.6201782226562
# Step 489200: loss_history = -792.1092529296875
# Step 489300: loss_history = -792.6032104492188
# Step 489400: loss_history = -793.1006469726562
# Step 489500: loss_history = -790.4558715820312
# Step 489600: loss_history = -790.4617919921875
# Step 489700: loss_history = -790.9410400390625
# Step 489800: loss_history = -791.42578125
# Step 489900: loss_history = -791.9136352539062
# Step 490000: loss_history = -792.4053955078125
# Step 490100: loss_history = -792.901611328125
# Step 490200: loss_history = -792.799072265625
# Step 490300: loss_history = -790.2715454101562
# Step 490400: loss_history = -790.7499389648438
# Step 490500: loss_history = -791.231689453125
# Step 490600: loss_history = -791.7188110351562
# Step 490700: loss_history = -792.2090454101562
# Step 490800: loss_history = -792.7031860351562
# Step 490900: loss_history = -793.2020263671875
# Step 491000: loss_history = -790.0808715820312
# Step 491100: loss_history = -790.5589599609375
# Step 491200: loss_history = -791.0397338867188
# Step 491300: loss_history = -791.5239868164062
# Step 491400: loss_history = -792.0135498046875
# Step 491500: loss_history = -792.5061645507812
# Step 491600: loss_history = -793.0030517578125
# Step 491700: loss_history = -791.6328735351562
# Step 491800: loss_history = -790.3680419921875
# Step 491900: loss_history = -790.8483276367188
# Step 492000: loss_history = -791.3316040039062
# Step 492100: loss_history = -791.8184204101562
# Step 492200: loss_history = -792.3101806640625
# Step 492300: loss_history = -792.8052978515625
# Step 492400: loss_history = -793.3045654296875
# Step 492500: loss_history = -790.1796264648438
# Step 492600: loss_history = -790.6566162109375
# Step 492700: loss_history = -791.1395263671875
# Step 492800: loss_history = -791.6251220703125
# Step 492900: loss_history = -792.1142578125
# Step 493000: loss_history = -792.6082763671875
# Step 493100: loss_history = -793.106201171875
# Step 493200: loss_history = -790.4515380859375
# Step 493300: loss_history = -790.4677734375
# Step 493400: loss_history = -790.9472045898438
# Step 493500: loss_history = -791.4321899414062
# Step 493600: loss_history = -791.9202880859375
# Step 493700: loss_history = -792.4122314453125
# Step 493800: loss_history = -792.9086303710938
# Step 493900: loss_history = -792.7760009765625
# Step 494000: loss_history = -790.2789916992188
# Step 494100: loss_history = -790.757568359375
# Step 494200: loss_history = -791.239501953125
# Step 494300: loss_history = -791.7266845703125
# Step 494400: loss_history = -792.21728515625
# Step 494500: loss_history = -792.7119140625
# Step 494600: loss_history = -793.2105712890625
# Step 494700: loss_history = -790.0896606445312
# Step 494800: loss_history = -790.568359375
# Step 494900: loss_history = -791.0491943359375
# Step 495000: loss_history = -791.5338745117188
# Step 495100: loss_history = -792.0233764648438
# Step 495200: loss_history = -792.5162963867188
# Step 495300: loss_history = -793.0133666992188
# Step 495400: loss_history = -791.572021484375
# Step 495500: loss_history = -790.3784790039062
# Step 495600: loss_history = -790.8585815429688
# Step 495700: loss_history = -791.3423461914062
# Step 495800: loss_history = -791.8295288085938
# Step 495900: loss_history = -792.3214721679688
# Step 496000: loss_history = -792.8170166015625
# Step 496100: loss_history = -793.3167114257812
# Step 496200: loss_history = -790.19140625
# Step 496300: loss_history = -790.6690063476562
# Step 496400: loss_history = -791.1513061523438
# Step 496500: loss_history = -791.6375732421875
# Step 496600: loss_history = -792.127197265625
# Step 496700: loss_history = -792.62158203125
# Step 496800: loss_history = -793.11962890625
# Step 496900: loss_history = -790.3475341796875
# Step 497000: loss_history = -790.4813232421875
# Step 497100: loss_history = -790.9612426757812
# Step 497200: loss_history = -791.446044921875
# Step 497300: loss_history = -791.9345703125
# Step 497400: loss_history = -792.4266967773438
# Step 497500: loss_history = -792.92333984375
# Step 497600: loss_history = -792.6563720703125
# Step 497700: loss_history = -790.2933349609375
# Step 497800: loss_history = -790.7726440429688
# Step 497900: loss_history = -791.2551879882812
# Step 498000: loss_history = -791.7421875
# Step 498100: loss_history = -792.2332763671875
# Step 498200: loss_history = -792.7279663085938
# Step 498300: loss_history = -793.2271118164062
# Step 498400: loss_history = -790.1061401367188
# Step 498500: loss_history = -790.5841674804688
# Step 498600: loss_history = -791.0658569335938
# Step 498700: loss_history = -791.5508422851562
# Step 498800: loss_history = -792.0403442382812
# Step 498900: loss_history = -792.5336303710938
# Step 499000: loss_history = -793.0311279296875
# Step 499100: loss_history = -791.4164428710938
# Step 499200: loss_history = -790.396484375
# Step 499300: loss_history = -790.8767700195312
# Step 499400: loss_history = -791.3604125976562
# Step 499500: loss_history = -791.8480834960938
# Step 499600: loss_history = -792.3402099609375
# Step 499700: loss_history = -792.836181640625
# Step 499800: loss_history = -793.3359375
# Step 499900: loss_history = -790.2103881835938
# Optimized Coordinates:
# Vertex 1: (-11.12000560760498, 9.0310640335083)
# Vertex 2: (-9.296539306640625, 10.530815124511719)
# Vertex 3: (-7.3026347160339355, 11.728507995605469)
# Vertex 4: (-5.142935752868652, 12.62704086303711)
# Vertex 5: (-2.8383629322052, 13.205888748168945)
# Vertex 6: (-0.4411471486091614, 13.43614673614502)
# Vertex 7: (1.9303669929504395, 13.3028564453125)
# Vertex 8: (4.264642715454102, 12.816743850708008)
# Vertex 9: (6.539275646209717, 11.969208717346191)
# Vertex 10: (8.73716926574707, 10.73292064666748)
# Vertex 11: (10.823243141174316, 9.060324668884277)
# Vertex 12: (12.716241836547852, 6.904977321624756)
# Vertex 13: (14.277061462402344, 4.266667366027832)
# Vertex 14: (15.339522361755371, 1.2343941926956177)
# Vertex 15: (15.774595260620117, -2.018723726272583)
# Vertex 16: (15.534048080444336, -5.26062536239624)
# Vertex 17: (14.623176574707031, -8.430940628051758)
# Vertex 18: (13.029288291931152, -11.417893409729004)
# Vertex 19: (10.775474548339844, -14.061314582824707)
# Vertex 20: (7.959530830383301, -16.178544998168945)
# Vertex 21: (4.749526500701904, -17.624065399169922)
# Vertex 22: (1.3300695419311523, -18.32598114013672)
# Vertex 23: (-2.121863842010498, -18.267684936523438)
# Vertex 24: (-5.492521286010742, -17.460886001586914)
# Vertex 25: (-8.578336715698242, -15.963417053222656)
# Vertex 26: (-11.203961372375488, -13.906688690185547)
# Vertex 27: (-13.266443252563477, -11.462140083312988)
# Vertex 28: (-14.744686126708984, -8.780941009521484)
# Vertex 29: (-15.660077095031738, -5.965531349182129)
# Vertex 30: (-16.0362548828125, -3.0815680027008057)
# Vertex 31: (-15.883602142333984, -0.2182101160287857)
# Vertex 32: (-15.234238624572754, 2.5320117473602295)
# Vertex 33: (-14.158598899841309, 5.033318042755127)
# Vertex 34: (-12.75760269165039, 7.205440521240234)
# Optimized Perimeter: 99.8311
# Optimized Area: 790.6887
# Theoretical maximum = (aprox 795)

# %%
plt.plot(loss_history)
plt.grid(True)
plt.xlabel("iteration")
plt.ylabel("loss")
plt.title("loss history - 34 Point Optimizer ")
plt.savefig("loss_history_34_RMSprop_500000its_lr0.0008.pdf")
