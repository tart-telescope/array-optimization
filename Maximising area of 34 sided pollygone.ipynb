# %%
import torch
import torch.optim as optim
from torch.autograd import Variable
import matplotlib.pyplot as plt
from torch import sqrt
import numpy as np
from matplotlib.animation import FuncAnimation
from IPython import display

# %%
# Define the number of variables
#n = 34

# Create a list of Variables for x and y
#x_variables = [torch.randn(1, requires_grad=True) for _ in range(n)]
#y_variables = [torch.randn(1, requires_grad=True) for _ in range(n)]

# Example: printing the variables
#for i in range(n):
    #print(f"x{i+1}:", x_variables[i].item())

#for i in range(n):
    #print(f"y{i+1}:", y_variables[i].item())

# Plot each set of data
#for i in range(n):
    #plt.plot(x_variables[i].detach().numpy(), y_variables[i].detach().numpy(), 'x', color='red', label=f'Set {i+1}')

    

#plt.xlabel('X')
#plt.ylabel('Y')
#plt.title('Plot of 34 sets of data')
#plt.show()

x1 = Variable(torch.randn(1)*1, requires_grad=True)
y1 = Variable(torch.randn(1)*1, requires_grad=True)
x2 = Variable(torch.randn(1)*1, requires_grad=True)
y2 = Variable(torch.randn(1)*1, requires_grad=True)
x3 = Variable(torch.randn(1)*1, requires_grad=True)
y3 = Variable(torch.randn(1)*1, requires_grad=True)
x4 = Variable(torch.randn(1)*1, requires_grad=True)
y4 = Variable(torch.randn(1)*1, requires_grad=True)
y5 = Variable(torch.randn(1)*1, requires_grad=True)
x5 = Variable(torch.randn(1)*1, requires_grad=True)
x6 = Variable(torch.randn(1)*1, requires_grad=True)
x7 = Variable(torch.randn(1)*1, requires_grad=True)
x8 = Variable(torch.randn(1)*1, requires_grad=True)
x9 = Variable(torch.randn(1)*1, requires_grad=True)
x10 = Variable(torch.randn(1)*1, requires_grad=True)
x11 = Variable(torch.randn(1)*1, requires_grad=True)
x12 = Variable(torch.randn(1)*1, requires_grad=True)
x13 = Variable(torch.randn(1)*1, requires_grad=True)
x14 = Variable(torch.randn(1)*1, requires_grad=True)
x15 = Variable(torch.randn(1)*1, requires_grad=True)
x16 = Variable(torch.randn(1)*1, requires_grad=True)
x17 = Variable(torch.randn(1)*1, requires_grad=True)
x18 = Variable(torch.randn(1)*1, requires_grad=True)
x19 = Variable(torch.randn(1)*1, requires_grad=True)
x20 = Variable(torch.randn(1)*1, requires_grad=True)
x21 = Variable(torch.randn(1)*1, requires_grad=True)
x22 = Variable(torch.randn(1)*1, requires_grad=True)
x23 = Variable(torch.randn(1)*1, requires_grad=True)
x24 = Variable(torch.randn(1)*1, requires_grad=True)
x25 = Variable(torch.randn(1)*1, requires_grad=True)
x26 = Variable(torch.randn(1)*1, requires_grad=True)
x27 = Variable(torch.randn(1)*1, requires_grad=True)
x28 = Variable(torch.randn(1)*1, requires_grad=True)
x29 = Variable(torch.randn(1)*1, requires_grad=True)
x30 = Variable(torch.randn(1)*1, requires_grad=True)
x31 = Variable(torch.randn(1)*1, requires_grad=True)
x32 = Variable(torch.randn(1)*1, requires_grad=True)
x33 = Variable(torch.randn(1)*1, requires_grad=True)
x34 = Variable(torch.randn(1)*1, requires_grad=True)
y6 = Variable(torch.randn(1)*1, requires_grad=True)
y7 = Variable(torch.randn(1)*1, requires_grad=True)
y8 = Variable(torch.randn(1)*1, requires_grad=True)
y9 = Variable(torch.randn(1)*1, requires_grad=True)
y10 = Variable(torch.randn(1)*1, requires_grad=True)
y11 = Variable(torch.randn(1)*1, requires_grad=True)
y12 = Variable(torch.randn(1)*1, requires_grad=True)
y13 = Variable(torch.randn(1)*1, requires_grad=True)
y14 = Variable(torch.randn(1)*1, requires_grad=True)
y15 = Variable(torch.randn(1)*1, requires_grad=True)
y16 = Variable(torch.randn(1)*1, requires_grad=True)
y17 = Variable(torch.randn(1)*1, requires_grad=True)
y18 = Variable(torch.randn(1)*1, requires_grad=True)
y19 = Variable(torch.randn(1)*1, requires_grad=True)
y20 = Variable(torch.randn(1)*1, requires_grad=True)
y21 = Variable(torch.randn(1)*1, requires_grad=True)
y22 = Variable(torch.randn(1)*1, requires_grad=True)
y23 = Variable(torch.randn(1)*1, requires_grad=True)
y24 = Variable(torch.randn(1)*1, requires_grad=True)
y25 = Variable(torch.randn(1)*1, requires_grad=True)
y26 = Variable(torch.randn(1)*1, requires_grad=True)
y27 = Variable(torch.randn(1)*1, requires_grad=True)
y28 = Variable(torch.randn(1)*1, requires_grad=True)
y29 = Variable(torch.randn(1)*1, requires_grad=True)
y30 = Variable(torch.randn(1)*1, requires_grad=True)
y31 = Variable(torch.randn(1)*1, requires_grad=True)
y32 = Variable(torch.randn(1)*1, requires_grad=True)
y33 = Variable(torch.randn(1)*1, requires_grad=True)
y34 = Variable(torch.randn(1)*1, requires_grad=True)

plt.plot(x1.detach().numpy(), y1.detach().numpy(), 'x',color='red',label='Starting locations')
plt.plot(x2.detach().numpy(), y2.detach().numpy(), 'x',color='red')
plt.plot(x3.detach().numpy(), y3.detach().numpy(), 'x',color='red')
plt.plot(x4.detach().numpy(), y4.detach().numpy(), 'x',color='red')
plt.plot(x5.detach().numpy(), y5.detach().numpy(), 'x',color='red')
plt.plot(x6.detach().numpy(), y6.detach().numpy(), 'x',color='red')
plt.plot(x7.detach().numpy(), y7.detach().numpy(), 'x',color='red')
plt.plot(x8.detach().numpy(), y8.detach().numpy(), 'x',color='red')
plt.plot(x9.detach().numpy(), y9.detach().numpy(), 'x',color='red')
plt.plot(x10.detach().numpy(), y10.detach().numpy(), 'x',color='red')
plt.plot(x11.detach().numpy(), y11.detach().numpy(), 'x',color='red')
plt.plot(x12.detach().numpy(), y12.detach().numpy(), 'x',color='red')
plt.plot(x13.detach().numpy(), y13.detach().numpy(), 'x',color='red')
plt.plot(x14.detach().numpy(), y14.detach().numpy(), 'x',color='red')
plt.plot(x15.detach().numpy(), y15.detach().numpy(), 'x',color='red')
plt.plot(x16.detach().numpy(), y16.detach().numpy(), 'x',color='red')
plt.plot(x17.detach().numpy(), y17.detach().numpy(), 'x',color='red')
plt.plot(x18.detach().numpy(), y18.detach().numpy(), 'x',color='red')
plt.plot(x19.detach().numpy(), y19.detach().numpy(), 'x',color='red')
plt.plot(x20.detach().numpy(), y20.detach().numpy(), 'x',color='red')
plt.plot(x21.detach().numpy(), y21.detach().numpy(), 'x',color='red')
plt.plot(x22.detach().numpy(), y22.detach().numpy(), 'x',color='red')
plt.plot(x23.detach().numpy(), y23.detach().numpy(), 'x',color='red')
plt.plot(x24.detach().numpy(), y24.detach().numpy(), 'x',color='red')
plt.plot(x25.detach().numpy(), y25.detach().numpy(), 'x',color='red')
plt.plot(x26.detach().numpy(), y26.detach().numpy(), 'x',color='red')
plt.plot(x27.detach().numpy(), y27.detach().numpy(), 'x',color='red')
plt.plot(x28.detach().numpy(), y28.detach().numpy(), 'x',color='red')
plt.plot(x29.detach().numpy(), y29.detach().numpy(), 'x',color='red')
plt.plot(x30.detach().numpy(), y30.detach().numpy(), 'x',color='red')
plt.plot(x31.detach().numpy(), y31.detach().numpy(), 'x',color='red')
plt.plot(x32.detach().numpy(), y32.detach().numpy(), 'x',color='red')
plt.plot(x33.detach().numpy(), y33.detach().numpy(), 'x',color='red')
plt.plot(x34.detach().numpy(), y34.detach().numpy(), 'x',color='red')

print(x1.detach().numpy(), y1.detach().numpy(), 'x')
print(x2.detach().numpy(), y2.detach().numpy(), 'x')
print(x3.detach().numpy(), y3.detach().numpy(), 'x')
print(x4.detach().numpy(), y4.detach().numpy(), 'x')
print(x5.detach().numpy(), y5.detach().numpy(), 'x')
print(x6.detach().numpy(), y6.detach().numpy(), 'x')
print(x7.detach().numpy(), y7.detach().numpy(), 'x')
print(x8.detach().numpy(), y8.detach().numpy(), 'x')
print(x9.detach().numpy(), y9.detach().numpy(), 'x')
print(x10.detach().numpy(), y10.detach().numpy(), 'x')
print(x11.detach().numpy(), y11.detach().numpy(), 'x')
print(x12.detach().numpy(), y12.detach().numpy(), 'x')
print(x13.detach().numpy(), y13.detach().numpy(), 'x')
print(x14.detach().numpy(), y14.detach().numpy(), 'x')
print(x15.detach().numpy(), y15.detach().numpy(), 'x')
print(x16.detach().numpy(), y16.detach().numpy(), 'x')
print(x17.detach().numpy(), y17.detach().numpy(), 'x')
print(x18.detach().numpy(), y18.detach().numpy(), 'x')
print(x19.detach().numpy(), y19.detach().numpy(), 'x')
print(x20.detach().numpy(), y20.detach().numpy(), 'x')
print(x21.detach().numpy(), y21.detach().numpy(), 'x')
print(x22.detach().numpy(), y22.detach().numpy(), 'x')
print(x23.detach().numpy(), y23.detach().numpy(), 'x')
print(x24.detach().numpy(), y24.detach().numpy(), 'x')
print(x25.detach().numpy(), y25.detach().numpy(), 'x')
print(x26.detach().numpy(), y26.detach().numpy(), 'x')
print(x27.detach().numpy(), y27.detach().numpy(), 'x')
print(x28.detach().numpy(), y28.detach().numpy(), 'x')
print(x29.detach().numpy(), y29.detach().numpy(), 'x')
print(x30.detach().numpy(), y30.detach().numpy(), 'x')
print(x31.detach().numpy(), y31.detach().numpy(), 'x')
print(x32.detach().numpy(), y32.detach().numpy(), 'x')
print(x33.detach().numpy(), y33.detach().numpy(), 'x')
print(x34.detach().numpy(), y34.detach().numpy(), 'x')



def compute_area(x1, y1, x2, y2, x3, y3, x4, y4, x5, y5, x6, y6,  x7, y7, x8, y8, x9, y9, x10, y10, x11, y11, x12, y12, x13, y13, x14, y14, x15, y15, x16, y16, x17, y17, x18, y18, x19, y19, x20, y20, x21, y21, x22, y22, x23, y23, x24, y24, x25, y25, x26, y26, x27, y27, x28, y28, x29, y29, x30, y30, x31, y31, x32, y32, x33, y33, x34, y34):


   #  area = 0.5 * |x1*y2 -x1*y4 -x3*y2 + x3*y4 -y1*x2 +y1*x4 +y3*x2 -y3*x4|

        return 0.5 * torch.abs((x1*y2 - y1*x2)+(x2*y3 - y2*x3)+(x3*y4 -y3*x4)+(x4*y5-y4*x5)+(x5*y6-y5*x6)+(x6*y7-y6*x7)+(x7*y8-y7*x8)+(x8*y9-y8*x9)+(x9*y10-y9*x10)+(x10*y11-y10*x11)+(x11*y12-y11*x12)+(x12*y13-y12*x13)+(x13*y14-y13*x14)+(x14*y15-y14*x15)+(x15*y16-y15*x16)+(x16*y17-y16*x17)+(x17*y18-y17*x18)+(x18*y19-y18*x19)+(x19*y20-y19*x20)+(x20*y21-y20*x21)+(x21*y22-y21*x22)+(x22*y23-y22*x23)+(x23*y24-y23*x24)+(x24*y25-y24*x25)+(x25*y26-y25*x26)+(x26*y27-y26*x27)+(x27*y28-y27*x28)+(x28*y29-y28*x29)+(x29*y30-y29*x30)+(x30*y31-y30*x31)+(x31*y32-y31*x32)+(x32*y33-y32*x33)+(x33*y34-y33*x34)+(x34*y1-y34*x1))
    


def compute_perimeter(x1, y1, x2, y2, x3, y3, x4, y4, x5, y5, x6, y6,  x7, y7, x8, y8, x9, y9, x10, y10, x11, y11, x12, y12, x13, y13, x14, y14, x15, y15, x16, y16, x17, y17, x18, y18, x19, y19, x20, y20, x21, y21, x22, y22, x23, y23, x24, y24, x25, y25, x26, y26, x27, y27, x28, y28, x29, y29, x30, y30, x31, y31, x32, y32, x33, y33, x34, y34):
   
    s1 = torch.sqrt((x2 - x1)**2 + (y2 - y1)**2)
    s2 = torch.sqrt((x3 - x2)**2 + (y3 - y2)**2)
    s3 = torch.sqrt((x4 - x3)**2 + (y4 - y3)**2)
    s4 = torch.sqrt((x5 - x4)**2 + (y5 - y4)**2)
    s5 = torch.sqrt((x6 - x5)**2 + (y6 - y5)**2)
    s6 = torch.sqrt((x7 - x6)**2 + (y7 - y6)**2)
    s7 = torch.sqrt((x8 - x7)**2 + (y8 - y7)**2)
    s8 = torch.sqrt((x9 - x8)**2 + (y9- y8)**2)
    s9 = torch.sqrt((x10 - x9)**2 + (y10 - y9)**2)
    s10 = torch.sqrt((x11 - x10)**2 + (y11 - y10)**2)
    s11 = torch.sqrt((x12 - x11)**2 + (y12 - y11)**2)
    s12= torch.sqrt((x13 - x12)**2 + (y13 - y12)**2)
    s13= torch.sqrt((x14 - x13)**2 + (y14 - y13)**2)
    s14= torch.sqrt((x15 - x14)**2 + (y15 - y14)**2)
    s15= torch.sqrt((x16 - x15)**2 + (y16 - y15)**2)
    s16= torch.sqrt((x17 - x16)**2 + (y17- y16)**2)
    s17= torch.sqrt((x18 - x17)**2 + (y18- y17)**2)
    s18= torch.sqrt((x19 - x18)**2 + (y19- y18)**2)
    s19= torch.sqrt((x20 - x19)**2 + (y20- y19)**2)
    s20= torch.sqrt((x21 - x20)**2 + (y21 - y20)**2)
    s21= torch.sqrt((x22 - x21)**2 + (y22 - y21)**2)
    s22= torch.sqrt((x23 - x22)**2 + (y23 - y22)**2)
    s23= torch.sqrt((x24 - x23)**2 + (y24 - y23)**2)
    s24= torch.sqrt((x25 - x24)**2 + (y25 - y24)**2)
    s25= torch.sqrt((x26 - x25)**2 + (y26 - y25)**2)
    s26= torch.sqrt((x27 - x26)**2 + (y27- y26)**2)
    s27= torch.sqrt((x28 - x27)**2 + (y28- y27)**2)
    s28= torch.sqrt((x29- x28)**2 + (y29- y28)**2)
    s29= torch.sqrt((x30- x29)**2 + (y30 - y29)**2)
    s30= torch.sqrt((x31 - x30)**2 + (y31 - y30)**2)
    s31= torch.sqrt((x32 - x31)**2 + (y32 - y31)**2)
    s32= torch.sqrt((x33 - x32)**2 + (y33 - y32)**2)
    s33= torch.sqrt((x34 - x33)**2 + (y34 - y33)**2)
    s34= torch.sqrt((x1 - x34)**2 + (y1 - y34)**2)
 
    return s1 + s2 + s3 + s4 + s5 + s6 + s7 + s8 + s9 + s10 + s11 + s12 + s13 + s14 + s15 + s16 + s17 + s18 + s19 + s20 + s21 + s22 + s23 + s24 + s25 + s26 + s27 + s28 + s29 + s30 +s31 + s32 + s33 + s34 



optimizer = optim.Adam([x1, y1, x2, y2, x3, y3, x4, y4, x5, y5, x6, y6, x7, y7, x8, y8, x9, y9, x10, y10, x11, y11, x12, y12, x13, y13, x14, y14, x15, y15, x16, y16, x17, y17, x18, y18, x19, y19, x20, y20, x21, y21, x22, y22, x23, y23, x24, y24, x25, y25, x26, y26, x27, y27, x28, y28, x29, y29, x30, y30, x31, y31, x32, y32, x33, y33, x34, y34], lr=.008)
#, momentum=0
steps = 500000

max_perimeter = 100

loss_history = []

# Optimization loop
for step in range(steps):
    # Compute area
    area = compute_area(x1, y1, x2, y2, x3, y3, x4, y4, x5, y5, x6, y6,  x7, y7, x8, y8, x9, y9, x10, y10, x11, y11, x12, y12, x13, y13, x14, y14, x15, y15, x16, y16, x17, y17, x18, y18, x19, y19, x20, y20, x21, y21, x22, y22, x23, y23, x24, y24, x25, y25, x26, y26, x27, y27, x28, y28, x29, y29, x30, y30, x31, y31, x32, y32, x33, y33, x34, y34)
    
    # Compute perimeter
    perimeter = compute_perimeter(x1, y1, x2, y2, x3, y3, x4, y4, x5, y5, x6, y6,  x7, y7, x8, y8, x9, y9, x10, y10, x11, y11, x12, y12, x13, y13, x14, y14, x15, y15, x16, y16, x17, y17, x18, y18, x19, y19, x20, y20, x21, y21, x22, y22, x23, y23, x24, y24, x25, y25, x26, y26, x27, y27, x28, y28, x29, y29, x30, y30, x31, y31, x32, y32, x33, y33, x34, y34)
    
    # apply a penalty if peremter of 100 units is exceeded (not really confindent in this step and the next step)
    perimeter_penalty = (torch.max(torch.tensor(0.), ((perimeter)**2 - (max_perimeter)**2))) #hmmmm
    
    # loss function
    loss = -area + perimeter_penalty**1
    #(torch.log(1/area) + perimeter_penalty**1)
    #-area + perimeter_penalty**1
    #(torch.log((1/area) + 1*perimeter_penalty**2))
    #(torch.log(1/area) + perimeter_penalty**1)  # hmmmm
    #loss = -area + perimeter_penalty**1
    # 2*perimeter_penalty - area
    
    
    # Zero gradients
    optimizer.zero_grad()
    
    # Compute gradients
    loss.backward()
    
    # Update parameters
    optimizer.step()

    loss_history.append(loss.item())

    if step % 100 == 0:
        print(f'Step {step}: loss_history = {loss.item()}') # Prints a value for loss function once every hundred iterations

optimized_x1 = x1.item()
optimized_y1 = y1.item()
optimized_x2 = x2.item()
optimized_y2 = y2.item()
optimized_x3 = x3.item()
optimized_y3 = y3.item()
optimized_x4 = x4.item()
optimized_y4 = y4.item()
optimized_x5 = x5.item()
optimized_y5 = y5.item()

optimized_x6 = x6.item()
optimized_x7 = x7.item()
optimized_x8 = x8.item()
optimized_x9 = x9.item()
optimized_x10 = x10.item()
optimized_x11 = x11.item()
optimized_x12 = x12.item()
optimized_x13 = x13.item()
optimized_x14 = x14.item()
optimized_x15 = x15.item()
optimized_x16 = x16.item()
optimized_x17 = x17.item()
optimized_x18 = x18.item()
optimized_x19 = x19.item()
optimized_x20 = x20.item()
optimized_x21 = x21.item()
optimized_x22 = x22.item()
optimized_x23 = x23.item()
optimized_x24 = x24.item()
optimized_x25 = x25.item()
optimized_x26 = x26.item()
optimized_x27 = x27.item()
optimized_x28 = x28.item()
optimized_x29 = x29.item()
optimized_x30 = x30.item()
optimized_x31 = x31.item()
optimized_x32 = x32.item()
optimized_x33 = x33.item()
optimized_x34 = x34.item()

optimized_y6 = y6.item()
optimized_y7 = y7.item()
optimized_y8 = y8.item()
optimized_y9 = y9.item()
optimized_y10 = y10.item()
optimized_y11 = y11.item()
optimized_y12 = y12.item()
optimized_y13 = y13.item()
optimized_y14 = y14.item()
optimized_y15 = y15.item()
optimized_y16 = y16.item()
optimized_y17 = y17.item()
optimized_y18 = y18.item()
optimized_y19 = y19.item()
optimized_y20 = y20.item()
optimized_y21 = y21.item()
optimized_y22 = y22.item()
optimized_y23 = y23.item()
optimized_y24 = y24.item()
optimized_y25 = y25.item()
optimized_y26 = y26.item()
optimized_y27 = y27.item()
optimized_y28 = y28.item()
optimized_y29 = y29.item()
optimized_y30 = y30.item()
optimized_y31 = y31.item()
optimized_y32 = y32.item()
optimized_y33 = y33.item()
optimized_y34 = y34.item()

# Print the optimized coords, area and perimeter (should be a square)
print("Optimized Coordinates:")
print("Vertex 1: ({}, {})".format(optimized_x1, optimized_y1))
print("Vertex 2: ({}, {})".format(optimized_x2, optimized_y2))
print("Vertex 3: ({}, {})".format(optimized_x3, optimized_y3))
print("Vertex 4: ({}, {})".format(optimized_x4, optimized_y4))
print("Vertex 5: ({}, {})".format(optimized_x5, optimized_y5))
print("Vertex 6: ({}, {})".format(optimized_x6, optimized_y6))
print("Vertex 7: ({}, {})".format(optimized_x7, optimized_y7))
print("Vertex 8: ({}, {})".format(optimized_x8, optimized_y8))
print("Vertex 9: ({}, {})".format(optimized_x9, optimized_y9))
print("Vertex 10: ({}, {})".format(optimized_x10, optimized_y10))
print("Vertex 11: ({}, {})".format(optimized_x11, optimized_y11))
print("Vertex 12: ({}, {})".format(optimized_x12, optimized_y12))
print("Vertex 13: ({}, {})".format(optimized_x13, optimized_y13))
print("Vertex 14: ({}, {})".format(optimized_x14, optimized_y14))
print("Vertex 15: ({}, {})".format(optimized_x15, optimized_y15))
print("Vertex 16: ({}, {})".format(optimized_x16, optimized_y16))
print("Vertex 17: ({}, {})".format(optimized_x17, optimized_y17))
print("Vertex 18: ({}, {})".format(optimized_x18, optimized_y18))
print("Vertex 19: ({}, {})".format(optimized_x19, optimized_y19))
print("Vertex 20: ({}, {})".format(optimized_x20, optimized_y20))
print("Vertex 21: ({}, {})".format(optimized_x21, optimized_y21))
print("Vertex 22: ({}, {})".format(optimized_x22, optimized_y22))
print("Vertex 23: ({}, {})".format(optimized_x23, optimized_y23))
print("Vertex 24: ({}, {})".format(optimized_x24, optimized_y24))
print("Vertex 25: ({}, {})".format(optimized_x25, optimized_y25))
print("Vertex 26: ({}, {})".format(optimized_x26, optimized_y26))
print("Vertex 27: ({}, {})".format(optimized_x27, optimized_y27))
print("Vertex 28: ({}, {})".format(optimized_x28, optimized_y28))
print("Vertex 29: ({}, {})".format(optimized_x29, optimized_y29))
print("Vertex 30: ({}, {})".format(optimized_x30, optimized_y30))
print("Vertex 31: ({}, {})".format(optimized_x31, optimized_y31))
print("Vertex 32: ({}, {})".format(optimized_x32, optimized_y32))
print("Vertex 33: ({}, {})".format(optimized_x33, optimized_y33))
print("Vertex 34: ({}, {})".format(optimized_x34, optimized_y34))

print("Optimized Perimeter: {:.4f}".format(compute_perimeter(x1, y1, x2, y2, x3, y3, x4, y4, x5, y5, x6, y6,  x7, y7, x8, y8, x9, y9, x10, y10, x11, y11, x12, y12, x13, y13, x14, y14, x15, y15, x16, y16, x17, y17, x18, y18, x19, y19, x20, y20, x21, y21, x22, y22, x23, y23, x24, y24, x25, y25, x26, y26, x27, y27, x28, y28, x29, y29, x30, y30, x31, y31, x32, y32, x33, y33, x34, y34).item()))
print("Optimized Area: {:.4f}".format(compute_area(x1, y1, x2, y2, x3, y3, x4, y4, x5, y5, x6, y6,  x7, y7, x8, y8, x9, y9, x10, y10, x11, y11, x12, y12, x13, y13, x14, y14, x15, y15, x16, y16, x17, y17, x18, y18, x19, y19, x20, y20, x21, y21, x22, y22, x23, y23, x24, y24, x25, y25, x26, y26, x27, y27, x28, y28, x29, y29, x30, y30, x31, y31, x32, y32, x33, y33, x34, y34).item()))
print("Theoretical maximum = (aprox 795)")


plt.gca().set_aspect('equal', adjustable='box')
plt.plot(x1.item(), y1.item(), 'o',color='black', label='final locations' )
plt.plot(x2.item(), y2.item(), 'o' ,color='black')
plt.plot(x3.item(), y3.item(), 'o',color='black')
plt.plot(x4.item(), y4.item(),'o',color='black')
plt.plot(x5.item(), y5.item(),'o',color='black')
plt.plot(x6.item(), y6.item(), 'o',color='black')
plt.plot(x7.item(), y7.item(), 'o',color='black')
plt.plot(x8.item(), y8.item(), 'o',color='black')
plt.plot(x9.item(), y9.item(),'o',color='black')
plt.plot(x10.item(), y10.item(),'o',color='black')
plt.plot(x11.item(), y11.item(), 'o' ,color='black')
plt.plot(x12.item(), y12.item(), 'o' ,color='black')
plt.plot(x13.item(), y13.item(), 'o',color='black')
plt.plot(x14.item(), y14.item(),'o',color='black')
plt.plot(x15.item(), y15.item(),'o',color='black')
plt.plot(x16.item(), y16.item(), 'o',color='black')
plt.plot(x17.item(), y17.item(), 'o',color='black')
plt.plot(x18.item(), y18.item(), 'o',color='black')
plt.plot(x19.item(), y19.item(),'o',color='black')
plt.plot(x20.item(), y20.item(),'o',color='black')
plt.plot(x21.item(), y21.item(), 'o' ,color='black')
plt.plot(x22.item(), y22.item(), 'o' ,color='black')
plt.plot(x23.item(), y23.item(), 'o',color='black')
plt.plot(x24.item(), y24.item(),'o',color='black')
plt.plot(x25.item(), y25.item(),'o',color='black')
plt.plot(x26.item(), y26.item(), 'o',color='black')
plt.plot(x27.item(), y27.item(), 'o',color='black')
plt.plot(x28.item(), y28.item(), 'o',color='black')
plt.plot(x29.item(), y29.item(),'o',color='black')
plt.plot(x30.item(), y30.item(),'o',color='black')
plt.plot(x31.item(), y31.item(), 'o' ,color='black')
plt.plot(x32.item(), y32.item(), 'o' ,color='black')
plt.plot(x33.item(), y33.item(), 'o',color='black')
plt.plot(x34.item(), y34.item(),'o',color='black')
plt.xlim(-30, 30)
plt.ylim(-30, 30)
plt.title("Optimising Area of a 34 Sided Pollygon While Constraining the Perimeter")
plt.xlabel('length units')
plt.ylabel('length units')
plt.legend()
plt.grid(color='gray', linestyle='-', linewidth=0.5)
plt.savefig("34_inital_and_final_coords_Adam_500000its_lr0.0008.pdf")
plt.show()
# Out:
# [-2.121496] [-0.08444081] x
# [-1.964285] [-1.0974178] x
# [1.344671] [0.13462393] x
# [-0.43012682] [0.75820386] x
# [0.8922144] [1.0124822] x
# [1.0830815] [0.56117934] x
# [-0.8066372] [0.48055506] x
# [-0.5029678] [1.3136921] x
# [-1.7812932] [-0.4106205] x
# [-1.4675564] [-0.5412286] x
# [-0.7288152] [-0.27992862] x
# [-0.68894076] [-0.9582304] x
# [-0.53493494] [0.5983616] x
# [-0.03599465] [-0.09840881] x
# [-0.89169693] [0.86747026] x
# [-0.5388048] [-1.6638024] x
# [0.04737981] [0.2189303] x
# [-0.03090119] [0.4559364] x
# [0.955307] [0.8394046] x
# [0.8934059] [1.3701516] x
# [2.091822] [-1.0427941] x
# [-0.9010248] [-0.0143366] x
# [-0.22407725] [-0.39507753] x
# [0.93267787] [-4.4192414] x
# [-0.20676212] [-0.01338304] x
# [-0.2627697] [-1.0898889] x
# [-0.39263612] [0.17140591] x
# [0.13200493] [-0.8938637] x
# [-0.53524894] [0.16320312] x
# [1.8861603] [-0.5321899] x
# [-0.5154302] [0.45211965] x
# [0.849809] [0.67432773] x
# [-0.2760493] [-2.3519819] x
# [-0.32073563] [-0.925692] x
# Step 0: loss_history = -0.6949489116668701
# Step 100: loss_history = -42.31412887573242
# Step 200: loss_history = -47.50236892700195
# Step 300: loss_history = -49.573917388916016
# Step 400: loss_history = -55.96584701538086
# Step 500: loss_history = -56.21893310546875
# Step 600: loss_history = -63.04572677612305
# Step 700: loss_history = -63.05963897705078
# Step 800: loss_history = -64.7310791015625
# Step 900: loss_history = -70.2091064453125
# Step 1000: loss_history = -70.47908020019531
# Step 1100: loss_history = -78.15130615234375
# Step 1200: loss_history = -78.48883056640625
# Step 1300: loss_history = -80.09086608886719
# Step 1400: loss_history = -87.70655822753906
# Step 1500: loss_history = -88.64083099365234
# Step 1600: loss_history = -90.86993408203125
# Step 1700: loss_history = -99.29893493652344
# Step 1800: loss_history = -100.96257019042969
# Step 1900: loss_history = -103.18904113769531
# Step 2000: loss_history = -113.47024536132812
# Step 2100: loss_history = -115.9056396484375
# Step 2200: loss_history = -118.8305892944336
# Step 2300: loss_history = -122.47733306884766
# Step 2400: loss_history = -131.9525604248047
# Step 2500: loss_history = -138.15017700195312
# Step 2600: loss_history = -142.55422973632812
# Step 2700: loss_history = -147.43096923828125
# Step 2800: loss_history = -152.75265502929688
# Step 2900: loss_history = -158.4756622314453
# Step 3000: loss_history = -164.47488403320312
# Step 3100: loss_history = -170.64271545410156
# Step 3200: loss_history = -177.19651794433594
# Step 3300: loss_history = -180.80966186523438
# Step 3400: loss_history = -184.680419921875
# Step 3500: loss_history = -190.1868896484375
# Step 3600: loss_history = -197.3525848388672
# Step 3700: loss_history = -198.33335876464844
# Step 3800: loss_history = -204.8728485107422
# Step 3900: loss_history = -207.29605102539062
# Step 4000: loss_history = -213.46566772460938
# Step 4100: loss_history = -215.64935302734375
# Step 4200: loss_history = -222.79916381835938
# Step 4300: loss_history = -224.81471252441406
# Step 4400: loss_history = -232.9888916015625
# Step 4500: loss_history = -235.00779724121094
# Step 4600: loss_history = -237.71563720703125
# Step 4700: loss_history = -242.17613220214844
# Step 4800: loss_history = -248.90777587890625
# Step 4900: loss_history = -251.88644409179688
# Step 5000: loss_history = -255.44097900390625
# Step 5100: loss_history = -260.27752685546875
# Step 5200: loss_history = -264.5993957519531
# Step 5300: loss_history = -272.13970947265625
# Step 5400: loss_history = -276.25531005859375
# Step 5500: loss_history = -280.8389587402344
# Step 5600: loss_history = -285.5890808105469
# Step 5700: loss_history = -290.5019836425781
# Step 5800: loss_history = -293.1880798339844
# Step 5900: loss_history = -296.32073974609375
# Step 6000: loss_history = -300.8653564453125
# Step 6100: loss_history = -306.0711975097656
# Step 6200: loss_history = -308.38726806640625
# Step 6300: loss_history = -312.2947998046875
# Step 6400: loss_history = -317.827880859375
# Step 6500: loss_history = -319.4826354980469
# Step 6600: loss_history = -324.6511535644531
# Step 6700: loss_history = -326.8345642089844
# Step 6800: loss_history = -331.9942626953125
# Step 6900: loss_history = -334.32708740234375
# Step 7000: loss_history = -339.8746032714844
# Step 7100: loss_history = -341.9665222167969
# Step 7200: loss_history = -344.3496398925781
# Step 7300: loss_history = -350.4539794921875
# Step 7400: loss_history = -354.28497314453125
# Step 7500: loss_history = -359.62896728515625
# Step 7600: loss_history = -362.58319091796875
# Step 7700: loss_history = -368.12493896484375
# Step 7800: loss_history = -372.4019775390625
# Step 7900: loss_history = -376.25677490234375
# Step 8000: loss_history = -379.4647216796875
# Step 8100: loss_history = -386.7195129394531
# Step 8200: loss_history = -391.2215270996094
# Step 8300: loss_history = -396.4683837890625
# Step 8400: loss_history = -402.69000244140625
# Step 8500: loss_history = -407.664794921875
# Step 8600: loss_history = -415.3936462402344
# Step 8700: loss_history = -420.5099182128906
# Step 8800: loss_history = -425.9889221191406
# Step 8900: loss_history = -432.997314453125
# Step 9000: loss_history = -440.45196533203125
# Step 9100: loss_history = -446.3501281738281
# Step 9200: loss_history = -453.2837219238281
# Step 9300: loss_history = -462.43402099609375
# Step 9400: loss_history = -469.33258056640625
# Step 9500: loss_history = -476.5601806640625
# Step 9600: loss_history = -485.0812072753906
# Step 9700: loss_history = -495.16790771484375
# Step 9800: loss_history = -502.9443054199219
# Step 9900: loss_history = -511.1402893066406
# Step 10000: loss_history = -519.4584350585938
# Step 10100: loss_history = -530.5504150390625
# Step 10200: loss_history = -538.4102172851562
# Step 10300: loss_history = -551.17822265625
# Step 10400: loss_history = -560.1217041015625
# Step 10500: loss_history = -569.351318359375
# Step 10600: loss_history = -579.4048461914062
# Step 10700: loss_history = -589.7733154296875
# Step 10800: loss_history = -599.98828125
# Step 10900: loss_history = -607.3853149414062
# Step 11000: loss_history = -614.4967041015625
# Step 11100: loss_history = -621.8565673828125
# Step 11200: loss_history = -629.609619140625
# Step 11300: loss_history = -636.7972412109375
# Step 11400: loss_history = -640.7406005859375
# Step 11500: loss_history = -645.1373291015625
# Step 11600: loss_history = -648.9456787109375
# Step 11700: loss_history = -652.3375244140625
# Step 11800: loss_history = -656.0466918945312
# Step 11900: loss_history = -658.4050903320312
# Step 12000: loss_history = -660.8869018554688
# Step 12100: loss_history = -663.6558837890625
# Step 12200: loss_history = -665.5634155273438
# Step 12300: loss_history = -667.7948608398438
# Step 12400: loss_history = -670.2164916992188
# Step 12500: loss_history = -671.5843505859375
# Step 12600: loss_history = -673.4656372070312
# Step 12700: loss_history = -674.2977294921875
# Step 12800: loss_history = -677.3745727539062
# Step 12900: loss_history = -678.7655029296875
# Step 13000: loss_history = -680.3148193359375
# Step 13100: loss_history = -681.90966796875
# Step 13200: loss_history = -683.6318359375
# Step 13300: loss_history = -685.476806640625
# Step 13400: loss_history = -687.13671875
# Step 13500: loss_history = -688.5250244140625
# Step 13600: loss_history = -689.484375
# Step 13700: loss_history = -691.3052978515625
# Step 13800: loss_history = -691.9705810546875
# Step 13900: loss_history = -693.508544921875
# Step 14000: loss_history = -694.7409057617188
# Step 14100: loss_history = -695.8262939453125
# Step 14200: loss_history = -696.7996215820312
# Step 14300: loss_history = -698.1484375
# Step 14400: loss_history = -699.615234375
# Step 14500: loss_history = -701.14306640625
# Step 14600: loss_history = -702.03466796875
# Step 14700: loss_history = -702.6801147460938
# Step 14800: loss_history = -703.7779541015625
# Step 14900: loss_history = -705.1859130859375
# Step 15000: loss_history = -706.1403198242188
# Step 15100: loss_history = -706.75
# Step 15200: loss_history = -708.042236328125
# Step 15300: loss_history = -707.317626953125
# Step 15400: loss_history = -709.7088623046875
# Step 15500: loss_history = -710.9215087890625
# Step 15600: loss_history = -711.5598754882812
# Step 15700: loss_history = -712.2511596679688
# Step 15800: loss_history = -713.7228393554688
# Step 15900: loss_history = -714.0126342773438
# Step 16000: loss_history = -715.1717529296875
# Step 16100: loss_history = -715.8023071289062
# Step 16200: loss_history = -716.6614379882812
# Step 16300: loss_history = -717.5196533203125
# Step 16400: loss_history = -718.2119750976562
# Step 16500: loss_history = -718.6884765625
# Step 16600: loss_history = -719.7747802734375
# Step 16700: loss_history = -720.3306274414062
# Step 16800: loss_history = -721.370849609375
# Step 16900: loss_history = -721.6474609375
# Step 17000: loss_history = -722.5411376953125
# Step 17100: loss_history = -723.1014404296875
# Step 17200: loss_history = -723.5152587890625
# Step 17300: loss_history = -724.5618896484375
# Step 17400: loss_history = -725.0424194335938
# Step 17500: loss_history = -725.3930053710938
# Step 17600: loss_history = -726.4688110351562
# Step 17700: loss_history = -726.8014526367188
# Step 17800: loss_history = -727.2036743164062
# Step 17900: loss_history = -727.9512939453125
# Step 18000: loss_history = -728.8857421875
# Step 18100: loss_history = -728.9774780273438
# Step 18200: loss_history = -729.3873901367188
# Step 18300: loss_history = -729.9666137695312
# Step 18400: loss_history = -730.8438720703125
# Step 18500: loss_history = -731.3349609375
# Step 18600: loss_history = -731.640380859375
# Step 18700: loss_history = -731.9200439453125
# Step 18800: loss_history = -732.3616943359375
# Step 18900: loss_history = -733.203369140625
# Step 19000: loss_history = -733.47216796875
# Step 19100: loss_history = -733.7130126953125
# Step 19200: loss_history = -734.283447265625
# Step 19300: loss_history = -735.318115234375
# Step 19400: loss_history = -735.21435546875
# Step 19500: loss_history = -736.160400390625
# Step 19600: loss_history = -736.400634765625
# Step 19700: loss_history = -736.6864013671875
# Step 19800: loss_history = -737.0498657226562
# Step 19900: loss_history = -737.4284057617188
# Step 20000: loss_history = -737.8588256835938
# Step 20100: loss_history = -738.1218872070312
# Step 20200: loss_history = -738.4163818359375
# Step 20300: loss_history = -738.9359741210938
# Step 20400: loss_history = -739.4675903320312
# Step 20500: loss_history = -739.8352661132812
# Step 20600: loss_history = -740.005615234375
# Step 20700: loss_history = -740.2476806640625
# Step 20800: loss_history = -740.8514404296875
# Step 20900: loss_history = -741.189697265625
# Step 21000: loss_history = -741.641845703125
# Step 21100: loss_history = -741.8079833984375
# Step 21200: loss_history = -742.164794921875
# Step 21300: loss_history = -742.7471923828125
# Step 21400: loss_history = -743.305908203125
# Step 21500: loss_history = -743.699951171875
# Step 21600: loss_history = -743.38916015625
# Step 21700: loss_history = -742.8252563476562
# Step 21800: loss_history = -743.3770141601562
# Step 21900: loss_history = -744.828369140625
# Step 22000: loss_history = -744.9697265625
# Step 22100: loss_history = -745.2022705078125
# Step 22200: loss_history = -745.546630859375
# Step 22300: loss_history = -745.994384765625
# Step 22400: loss_history = -745.257080078125
# Step 22500: loss_history = -744.1450805664062
# Step 22600: loss_history = -745.993408203125
# Step 22700: loss_history = -746.8479614257812
# Step 22800: loss_history = -747.0858154296875
# Step 22900: loss_history = -747.59765625
# Step 23000: loss_history = -747.78125
# Step 23100: loss_history = -747.7967529296875
# Step 23200: loss_history = -747.73681640625
# Step 23300: loss_history = -748.2310791015625
# Step 23400: loss_history = -748.7686157226562
# Step 23500: loss_history = -749.0714111328125
# Step 23600: loss_history = -748.7757568359375
# Step 23700: loss_history = -749.063720703125
# Step 23800: loss_history = -749.5841064453125
# Step 23900: loss_history = -748.36376953125
# Step 24000: loss_history = -750.073486328125
# Step 24100: loss_history = -750.111083984375
# Step 24200: loss_history = -750.52001953125
# Step 24300: loss_history = -750.82958984375
# Step 24400: loss_history = -750.6433715820312
# Step 24500: loss_history = -751.0276489257812
# Step 24600: loss_history = -751.538818359375
# Step 24700: loss_history = -751.369140625
# Step 24800: loss_history = -751.6138916015625
# Step 24900: loss_history = -752.0228271484375
# Step 25000: loss_history = -752.3589477539062
# Step 25100: loss_history = -752.1549072265625
# Step 25200: loss_history = -752.47705078125
# Step 25300: loss_history = -753.0777587890625
# Step 25400: loss_history = -752.8333740234375
# Step 25500: loss_history = -753.09033203125
# Step 25600: loss_history = -753.3504638671875
# Step 25700: loss_history = -753.3394775390625
# Step 25800: loss_history = -753.656494140625
# Step 25900: loss_history = -754.2293701171875
# Step 26000: loss_history = -753.9520874023438
# Step 26100: loss_history = -754.1200561523438
# Step 26200: loss_history = -754.545166015625
# Step 26300: loss_history = -754.4327392578125
# Step 26400: loss_history = -754.7354125976562
# Step 26500: loss_history = -755.1632080078125
# Step 26600: loss_history = -754.940185546875
# Step 26700: loss_history = -755.4091796875
# Step 26800: loss_history = -755.6483764648438
# Step 26900: loss_history = -755.4470825195312
# Step 27000: loss_history = -755.2825317382812
# Step 27100: loss_history = -755.7097778320312
# Step 27200: loss_history = -756.0985717773438
# Step 27300: loss_history = -756.6098022460938
# Step 27400: loss_history = -756.2347412109375
# Step 27500: loss_history = -756.7886962890625
# Step 27600: loss_history = -756.6630249023438
# Step 27700: loss_history = -757.0054931640625
# Step 27800: loss_history = -757.09716796875
# Step 27900: loss_history = -756.926025390625
# Step 28000: loss_history = -756.4609375
# Step 28100: loss_history = -757.3876953125
# Step 28200: loss_history = -757.84521484375
# Step 28300: loss_history = -757.7852783203125
# Step 28400: loss_history = -757.6689453125
# Step 28500: loss_history = -758.2958984375
# Step 28600: loss_history = -758.2702026367188
# Step 28700: loss_history = -758.7977294921875
# Step 28800: loss_history = -758.388671875
# Step 28900: loss_history = -758.6756591796875
# Step 29000: loss_history = -758.6417236328125
# Step 29100: loss_history = -758.949462890625
# Step 29200: loss_history = -759.5284423828125
# Step 29300: loss_history = -759.0357666015625
# Step 29400: loss_history = -758.8629760742188
# Step 29500: loss_history = -759.5671997070312
# Step 29600: loss_history = -760.1205444335938
# Step 29700: loss_history = -759.6788940429688
# Step 29800: loss_history = -760.2695922851562
# Step 29900: loss_history = -759.1139526367188
# Step 30000: loss_history = -760.3023681640625
# Step 30100: loss_history = -760.3588256835938
# Step 30200: loss_history = -760.6809692382812
# Step 30300: loss_history = -760.7203369140625
# Step 30400: loss_history = -760.7991943359375
# Step 30500: loss_history = -759.7796630859375
# Step 30600: loss_history = -760.986328125
# Step 30700: loss_history = -761.1021728515625
# Step 30800: loss_history = -761.29150390625
# Step 30900: loss_history = -761.3421630859375
# Step 31000: loss_history = -761.5026245117188
# Step 31100: loss_history = -760.5518188476562
# Step 31200: loss_history = -761.59326171875
# Step 31300: loss_history = -762.0440063476562
# Step 31400: loss_history = -761.9916381835938
# Step 31500: loss_history = -762.02392578125
# Step 31600: loss_history = -762.277099609375
# Step 31700: loss_history = -761.28662109375
# Step 31800: loss_history = -762.2467651367188
# Step 31900: loss_history = -762.58642578125
# Step 32000: loss_history = -762.7713623046875
# Step 32100: loss_history = -762.8685913085938
# Step 32200: loss_history = -763.0040283203125
# Step 32300: loss_history = -762.490478515625
# Step 32400: loss_history = -762.5421752929688
# Step 32500: loss_history = -763.1063232421875
# Step 32600: loss_history = -763.6553344726562
# Step 32700: loss_history = -763.299072265625
# Step 32800: loss_history = -763.8797607421875
# Step 32900: loss_history = -763.341552734375
# Step 33000: loss_history = -762.546875
# Step 33100: loss_history = -763.7451782226562
# Step 33200: loss_history = -764.0479125976562
# Step 33300: loss_history = -763.9382934570312
# Step 33400: loss_history = -763.9199829101562
# Step 33500: loss_history = -764.388916015625
# Step 33600: loss_history = -763.399169921875
# Step 33700: loss_history = -764.5235595703125
# Step 33800: loss_history = -764.3851318359375
# Step 33900: loss_history = -764.763916015625
# Step 34000: loss_history = -764.5283203125
# Step 34100: loss_history = -765.1309814453125
# Step 34200: loss_history = -764.7135620117188
# Step 34300: loss_history = -764.2779541015625
# Step 34400: loss_history = -765.1926879882812
# Step 34500: loss_history = -765.0423583984375
# Step 34600: loss_history = -765.57568359375
# Step 34700: loss_history = -765.1788330078125
# Step 34800: loss_history = -765.6663818359375
# Step 34900: loss_history = -764.9544067382812
# Step 35000: loss_history = -765.569091796875
# Step 35100: loss_history = -765.9322509765625
# Step 35200: loss_history = -765.6954956054688
# Step 35300: loss_history = -766.044677734375
# Step 35400: loss_history = -765.9005737304688
# Step 35500: loss_history = -765.392333984375
# Step 35600: loss_history = -765.897705078125
# Step 35700: loss_history = -766.146240234375
# Step 35800: loss_history = -766.5555419921875
# Step 35900: loss_history = -766.3209228515625
# Step 36000: loss_history = -765.2179565429688
# Step 36100: loss_history = -766.2767333984375
# Step 36200: loss_history = -766.1200561523438
# Step 36300: loss_history = -766.9462890625
# Step 36400: loss_history = -766.679443359375
# Step 36500: loss_history = -766.0574951171875
# Step 36600: loss_history = -766.8352661132812
# Step 36700: loss_history = -766.471435546875
# Step 36800: loss_history = -767.2947998046875
# Step 36900: loss_history = -767.08935546875
# Step 37000: loss_history = -767.099609375
# Step 37100: loss_history = -767.4061279296875
# Step 37200: loss_history = -766.9547729492188
# Step 37300: loss_history = -767.6712036132812
# Step 37400: loss_history = -767.545654296875
# Step 37500: loss_history = -767.991455078125
# Step 37600: loss_history = -767.6619873046875
# Step 37700: loss_history = -767.473388671875
# Step 37800: loss_history = -768.2640991210938
# Step 37900: loss_history = -767.9154052734375
# Step 38000: loss_history = -768.2061767578125
# Step 38100: loss_history = -768.2461547851562
# Step 38200: loss_history = -767.8333129882812
# Step 38300: loss_history = -767.8016357421875
# Step 38400: loss_history = -768.4111328125
# Step 38500: loss_history = -768.550048828125
# Step 38600: loss_history = -768.6885375976562
# Step 38700: loss_history = -768.4066772460938
# Step 38800: loss_history = -768.82568359375
# Step 38900: loss_history = -768.9838256835938
# Step 39000: loss_history = -768.7551879882812
# Step 39100: loss_history = -768.9702758789062
# Step 39200: loss_history = -769.024169921875
# Step 39300: loss_history = -769.1907958984375
# Step 39400: loss_history = -769.564453125
# Step 39500: loss_history = -768.995849609375
# Step 39600: loss_history = -768.801513671875
# Step 39700: loss_history = -769.503662109375
# Step 39800: loss_history = -769.534423828125
# Step 39900: loss_history = -769.865478515625
# Step 40000: loss_history = -769.5899658203125
# Step 40100: loss_history = -769.2174072265625
# Step 40200: loss_history = -769.8450317382812
# Step 40300: loss_history = -769.7781982421875
# Step 40400: loss_history = -769.8239135742188
# Step 40500: loss_history = -769.6593017578125
# Step 40600: loss_history = -769.7235107421875
# Step 40700: loss_history = -770.1753540039062
# Step 40800: loss_history = -770.5399780273438
# Step 40900: loss_history = -770.182373046875
# Step 41000: loss_history = -769.9524536132812
# Step 41100: loss_history = -770.3649291992188
# Step 41200: loss_history = -770.295654296875
# Step 41300: loss_history = -770.6614990234375
# Step 41400: loss_history = -770.824462890625
# Step 41500: loss_history = -770.530029296875
# Step 41600: loss_history = -770.3809814453125
# Step 41700: loss_history = -770.9400024414062
# Step 41800: loss_history = -770.9100341796875
# Step 41900: loss_history = -770.9904174804688
# Step 42000: loss_history = -770.9772338867188
# Step 42100: loss_history = -770.5950317382812
# Step 42200: loss_history = -771.3936767578125
# Step 42300: loss_history = -771.2794799804688
# Step 42400: loss_history = -771.6151733398438
# Step 42500: loss_history = -771.045166015625
# Step 42600: loss_history = -771.1572265625
# Step 42700: loss_history = -771.8213500976562
# Step 42800: loss_history = -771.42529296875
# Step 42900: loss_history = -771.3968505859375
# Step 43000: loss_history = -771.57470703125
# Step 43100: loss_history = -771.513427734375
# Step 43200: loss_history = -771.6550903320312
# Step 43300: loss_history = -771.1710205078125
# Step 43400: loss_history = -771.74462890625
# Step 43500: loss_history = -771.6185913085938
# Step 43600: loss_history = -771.0444946289062
# Step 43700: loss_history = -772.0477294921875
# Step 43800: loss_history = -771.9401245117188
# Step 43900: loss_history = -772.2542724609375
# Step 44000: loss_history = -772.1983032226562
# Step 44100: loss_history = -772.069091796875
# Step 44200: loss_history = -772.6852416992188
# Step 44300: loss_history = -772.4207763671875
# Step 44400: loss_history = -772.1195068359375
# Step 44500: loss_history = -772.637451171875
# Step 44600: loss_history = -772.7706909179688
# Step 44700: loss_history = -772.50732421875
# Step 44800: loss_history = -772.5877685546875
# Step 44900: loss_history = -773.0109252929688
# Step 45000: loss_history = -772.7028198242188
# Step 45100: loss_history = -772.7423095703125
# Step 45200: loss_history = -771.4171142578125
# Step 45300: loss_history = -772.7996826171875
# Step 45400: loss_history = -772.8845825195312
# Step 45500: loss_history = -773.3277587890625
# Step 45600: loss_history = -773.2308959960938
# Step 45700: loss_history = -773.033447265625
# Step 45800: loss_history = -773.1009521484375
# Step 45900: loss_history = -773.5604248046875
# Step 46000: loss_history = -773.32275390625
# Step 46100: loss_history = -773.192626953125
# Step 46200: loss_history = -772.75830078125
# Step 46300: loss_history = -773.474609375
# Step 46400: loss_history = -773.4605712890625
# Step 46500: loss_history = -773.872802734375
# Step 46600: loss_history = -773.673828125
# Step 46700: loss_history = -773.485107421875
# Step 46800: loss_history = -773.713623046875
# Step 46900: loss_history = -774.18603515625
# Step 47000: loss_history = -773.6416625976562
# Step 47100: loss_history = -773.8709716796875
# Step 47200: loss_history = -772.7503662109375
# Step 47300: loss_history = -774.05029296875
# Step 47400: loss_history = -773.911865234375
# Step 47500: loss_history = -774.189453125
# Step 47600: loss_history = -774.4544677734375
# Step 47700: loss_history = -774.254638671875
# Step 47800: loss_history = -774.185791015625
# Step 47900: loss_history = -774.3912963867188
# Step 48000: loss_history = -774.4903564453125
# Step 48100: loss_history = -774.489013671875
# Step 48200: loss_history = -774.6358032226562
# Step 48300: loss_history = -774.84130859375
# Step 48400: loss_history = -774.3314819335938
# Step 48500: loss_history = -774.6103515625
# Step 48600: loss_history = -773.3881225585938
# Step 48700: loss_history = -774.80908203125
# Step 48800: loss_history = -774.5042724609375
# Step 48900: loss_history = -774.7490234375
# Step 49000: loss_history = -775.2322998046875
# Step 49100: loss_history = -774.8547973632812
# Step 49200: loss_history = -774.842041015625
# Step 49300: loss_history = -774.9625244140625
# Step 49400: loss_history = -775.2225341796875
# Step 49500: loss_history = -775.0830078125
# Step 49600: loss_history = -775.0795288085938
# Step 49700: loss_history = -775.3496704101562
# Step 49800: loss_history = -775.265625
# Step 49900: loss_history = -775.2216186523438
# Step 50000: loss_history = -775.327392578125
# Step 50100: loss_history = -775.7584838867188
# Step 50200: loss_history = -775.3593139648438
# Step 50300: loss_history = -775.3673095703125
# Step 50400: loss_history = -775.901123046875
# Step 50500: loss_history = -775.846435546875
# Step 50600: loss_history = -775.5115966796875
# Step 50700: loss_history = -775.3814086914062
# Step 50800: loss_history = -775.9534301757812
# Step 50900: loss_history = -775.98388671875
# Step 51000: loss_history = -775.714599609375
# Step 51100: loss_history = -775.6799926757812
# Step 51200: loss_history = -776.0429077148438
# Step 51300: loss_history = -776.1358642578125
# Step 51400: loss_history = -775.9765014648438
# Step 51500: loss_history = -776.0383911132812
# Step 51600: loss_history = -775.1568603515625
# Step 51700: loss_history = -776.1997680664062
# Step 51800: loss_history = -776.03466796875
# Step 51900: loss_history = -776.3970947265625
# Step 52000: loss_history = -775.2193603515625
# Step 52100: loss_history = -776.1363525390625
# Step 52200: loss_history = -776.1503295898438
# Step 52300: loss_history = -776.5482788085938
# Step 52400: loss_history = -776.7288208007812
# Step 52500: loss_history = -776.3654174804688
# Step 52600: loss_history = -776.4164428710938
# Step 52700: loss_history = -776.6578979492188
# Step 52800: loss_history = -776.8660888671875
# Step 52900: loss_history = -776.5264892578125
# Step 53000: loss_history = -776.544189453125
# Step 53100: loss_history = -776.792724609375
# Step 53200: loss_history = -777.0966796875
# Step 53300: loss_history = -776.7962646484375
# Step 53400: loss_history = -776.6981201171875
# Step 53500: loss_history = -776.954345703125
# Step 53600: loss_history = -777.1766357421875
# Step 53700: loss_history = -776.857421875
# Step 53800: loss_history = -776.8812866210938
# Step 53900: loss_history = -777.0693969726562
# Step 54000: loss_history = -777.459228515625
# Step 54100: loss_history = -777.171630859375
# Step 54200: loss_history = -777.087890625
# Step 54300: loss_history = -777.0512084960938
# Step 54400: loss_history = -777.5635986328125
# Step 54500: loss_history = -777.24609375
# Step 54600: loss_history = -777.1104736328125
# Step 54700: loss_history = -777.21875
# Step 54800: loss_history = -776.6890258789062
# Step 54900: loss_history = -777.4905395507812
# Step 55000: loss_history = -777.3597412109375
# Step 55100: loss_history = -777.479736328125
# Step 55200: loss_history = -777.5986328125
# Step 55300: loss_history = -777.5972290039062
# Step 55400: loss_history = -777.443359375
# Step 55500: loss_history = -777.4968872070312
# Step 55600: loss_history = -777.8012084960938
# Step 55700: loss_history = -777.7622680664062
# Step 55800: loss_history = -777.7028198242188
# Step 55900: loss_history = -777.7435302734375
# Step 56000: loss_history = -777.7820434570312
# Step 56100: loss_history = -778.0579833984375
# Step 56200: loss_history = -777.8244018554688
# Step 56300: loss_history = -777.8373413085938
# Step 56400: loss_history = -778.0264282226562
# Step 56500: loss_history = -778.26416015625
# Step 56600: loss_history = -778.0113525390625
# Step 56700: loss_history = -777.919189453125
# Step 56800: loss_history = -778.0886840820312
# Step 56900: loss_history = -776.964111328125
# Step 57000: loss_history = -778.180908203125
# Step 57100: loss_history = -778.0531616210938
# Step 57200: loss_history = -778.1318969726562
# Step 57300: loss_history = -778.461181640625
# Step 57400: loss_history = -778.4161376953125
# Step 57500: loss_history = -778.3704223632812
# Step 57600: loss_history = -778.2342529296875
# Step 57700: loss_history = -778.4579467773438
# Step 57800: loss_history = -778.6992797851562
# Step 57900: loss_history = -778.4262084960938
# Step 58000: loss_history = -778.3485107421875
# Step 58100: loss_history = -778.5201416015625
# Step 58200: loss_history = -777.0225830078125
# Step 58300: loss_history = -778.699462890625
# Step 58400: loss_history = -778.5511474609375
# Step 58500: loss_history = -778.6270751953125
# Step 58600: loss_history = -778.7020263671875
# Step 58700: loss_history = -778.89892578125
# Step 58800: loss_history = -778.7724609375
# Step 58900: loss_history = -778.6012573242188
# Step 59000: loss_history = -779.0203857421875
# Step 59100: loss_history = -777.8715209960938
# Step 59200: loss_history = -778.934326171875
# Step 59300: loss_history = -778.8451538085938
# Step 59400: loss_history = -778.888916015625
# Step 59500: loss_history = -778.9737548828125
# Step 59600: loss_history = -779.2713012695312
# Step 59700: loss_history = -778.9528198242188
# Step 59800: loss_history = -778.9072265625
# Step 59900: loss_history = -779.1060791015625
# Step 60000: loss_history = -777.8609619140625
# Step 60100: loss_history = -779.2758178710938
# Step 60200: loss_history = -779.1513671875
# Step 60300: loss_history = -779.2510986328125
# Step 60400: loss_history = -779.3308715820312
# Step 60500: loss_history = -779.5488891601562
# Step 60600: loss_history = -779.3441772460938
# Step 60700: loss_history = -779.25390625
# Step 60800: loss_history = -779.4545288085938
# Step 60900: loss_history = -779.631103515625
# Step 61000: loss_history = -779.6915283203125
# Step 61100: loss_history = -779.39404296875
# Step 61200: loss_history = -779.4160766601562
# Step 61300: loss_history = -779.6541748046875
# Step 61400: loss_history = -779.7920532226562
# Step 61500: loss_history = -779.6627197265625
# Step 61600: loss_history = -779.5283203125
# Step 61700: loss_history = -779.4671630859375
# Step 61800: loss_history = -779.6159057617188
# Step 61900: loss_history = -779.6561889648438
# Step 62000: loss_history = -779.9722900390625
# Step 62100: loss_history = -780.1880493164062
# Step 62200: loss_history = -779.8952026367188
# Step 62300: loss_history = -779.736572265625
# Step 62400: loss_history = -779.686279296875
# Step 62500: loss_history = -780.2786254882812
# Step 62600: loss_history = -780.2841796875
# Step 62700: loss_history = -780.034912109375
# Step 62800: loss_history = -779.7352294921875
# Step 62900: loss_history = -779.9202880859375
# Step 63000: loss_history = -780.3556518554688
# Step 63100: loss_history = -780.3985595703125
# Step 63200: loss_history = -780.0525512695312
# Step 63300: loss_history = -779.97705078125
# Step 63400: loss_history = -779.9993286132812
# Step 63500: loss_history = -778.8859252929688
# Step 63600: loss_history = -780.4275512695312
# Step 63700: loss_history = -780.1118774414062
# Step 63800: loss_history = -780.0700073242188
# Step 63900: loss_history = -780.2985229492188
# Step 64000: loss_history = -780.5281982421875
# Step 64100: loss_history = -780.4771118164062
# Step 64200: loss_history = -780.288818359375
# Step 64300: loss_history = -780.1837158203125
# Step 64400: loss_history = -780.4346923828125
# Step 64500: loss_history = -779.7237548828125
# Step 64600: loss_history = -780.5516967773438
# Step 64700: loss_history = -780.4073486328125
# Step 64800: loss_history = -780.4769287109375
# Step 64900: loss_history = -780.75537109375
# Step 65000: loss_history = -779.9798583984375
# Step 65100: loss_history = -780.7714233398438
# Step 65200: loss_history = -780.509765625
# Step 65300: loss_history = -780.584716796875
# Step 65400: loss_history = -780.6534423828125
# Step 65500: loss_history = -780.0872192382812
# Step 65600: loss_history = -780.7733154296875
# Step 65700: loss_history = -780.6485595703125
# Step 65800: loss_history = -780.718994140625
# Step 65900: loss_history = -781.0054321289062
# Step 66000: loss_history = -779.9257202148438
# Step 66100: loss_history = -780.943359375
# Step 66200: loss_history = -780.7996215820312
# Step 66300: loss_history = -780.8728637695312
# Step 66400: loss_history = -781.1677856445312
# Step 66500: loss_history = -781.1162109375
# Step 66600: loss_history = -781.0922241210938
# Step 66700: loss_history = -780.9669189453125
# Step 66800: loss_history = -780.8419799804688
# Step 66900: loss_history = -781.0592041015625
# Step 67000: loss_history = -780.9635009765625
# Step 67100: loss_history = -781.2800903320312
# Step 67200: loss_history = -781.1639404296875
# Step 67300: loss_history = -781.0322875976562
# Step 67400: loss_history = -780.9898681640625
# Step 67500: loss_history = -781.4083251953125
# Step 67600: loss_history = -781.4976196289062
# Step 67700: loss_history = -781.3477783203125
# Step 67800: loss_history = -781.206298828125
# Step 67900: loss_history = -781.1409301757812
# Step 68000: loss_history = -781.558837890625
# Step 68100: loss_history = -781.7109985351562
# Step 68200: loss_history = -781.437744140625
# Step 68300: loss_history = -781.4055786132812
# Step 68400: loss_history = -781.33349609375
# Step 68500: loss_history = -781.4769287109375
# Step 68600: loss_history = -781.8564453125
# Step 68700: loss_history = -781.6617431640625
# Step 68800: loss_history = -781.3065185546875
# Step 68900: loss_history = -781.3617553710938
# Step 69000: loss_history = -781.4644775390625
# Step 69100: loss_history = -780.4664306640625
# Step 69200: loss_history = -781.8048095703125
# Step 69300: loss_history = -781.553955078125
# Step 69400: loss_history = -781.4346923828125
# Step 69500: loss_history = -781.6761474609375
# Step 69600: loss_history = -780.5560913085938
# Step 69700: loss_history = -781.96044921875
# Step 69800: loss_history = -781.6605224609375
# Step 69900: loss_history = -781.5106201171875
# Step 70000: loss_history = -781.7208862304688
# Step 70100: loss_history = -781.849609375
# Step 70200: loss_history = -782.1464233398438
# Step 70300: loss_history = -781.851318359375
# Step 70400: loss_history = -781.7932739257812
# Step 70500: loss_history = -781.938232421875
# Step 70600: loss_history = -782.0798950195312
# Step 70700: loss_history = -780.3461303710938
# Step 70800: loss_history = -782.1454467773438
# Step 70900: loss_history = -781.939208984375
# Step 71000: loss_history = -782.0006713867188
# Step 71100: loss_history = -782.0684814453125
# Step 71200: loss_history = -782.2710571289062
# Step 71300: loss_history = -782.2813110351562
# Step 71400: loss_history = -782.1193237304688
# Step 71500: loss_history = -782.1152954101562
# Step 71600: loss_history = -782.0697631835938
# Step 71700: loss_history = -782.2376098632812
# Step 71800: loss_history = -782.5482177734375
# Step 71900: loss_history = -782.3419799804688
# Step 72000: loss_history = -782.139892578125
# Step 72100: loss_history = -781.9669799804688
# Step 72200: loss_history = -782.2701416015625
# Step 72300: loss_history = -782.557861328125
# Step 72400: loss_history = -782.5969848632812
# Step 72500: loss_history = -782.3306274414062
# Step 72600: loss_history = -782.1458129882812
# Step 72700: loss_history = -782.12646484375
# Step 72800: loss_history = -782.49609375
# Step 72900: loss_history = -782.694580078125
# Step 73000: loss_history = -782.46630859375
# Step 73100: loss_history = -782.3660278320312
# Step 73200: loss_history = -782.454345703125
# Step 73300: loss_history = -782.5548095703125
# Step 73400: loss_history = -782.775390625
# Step 73500: loss_history = -782.6775512695312
# Step 73600: loss_history = -782.4954833984375
# Step 73700: loss_history = -782.4639892578125
# Step 73800: loss_history = -782.3912353515625
# Step 73900: loss_history = -782.7376098632812
# Step 74000: loss_history = -782.752197265625
# Step 74100: loss_history = -782.7894287109375
# Step 74200: loss_history = -782.56884765625
# Step 74300: loss_history = -782.5948486328125
# Step 74400: loss_history = -782.5833129882812
# Step 74500: loss_history = -782.7991333007812
# Step 74600: loss_history = -782.950439453125
# Step 74700: loss_history = -782.8543090820312
# Step 74800: loss_history = -782.6817016601562
# Step 74900: loss_history = -782.7427368164062
# Step 75000: loss_history = -782.8585205078125
# Step 75100: loss_history = -783.0740966796875
# Step 75200: loss_history = -783.197265625
# Step 75300: loss_history = -782.9388427734375
# Step 75400: loss_history = -782.8089599609375
# Step 75500: loss_history = -782.8038940429688
# Step 75600: loss_history = -783.1157836914062
# Step 75700: loss_history = -781.8002319335938
# Step 75800: loss_history = -783.1866455078125
# Step 75900: loss_history = -782.9784545898438
# Step 76000: loss_history = -782.8353271484375
# Step 76100: loss_history = -783.013671875
# Step 76200: loss_history = -782.8804931640625
# Step 76300: loss_history = -782.381103515625
# Step 76400: loss_history = -783.3050537109375
# Step 76500: loss_history = -783.1325073242188
# Step 76600: loss_history = -783.01904296875
# Step 76700: loss_history = -783.0250244140625
# Step 76800: loss_history = -783.2578125
# Step 76900: loss_history = -783.5223999023438
# Step 77000: loss_history = -783.3221435546875
# Step 77100: loss_history = -783.1171264648438
# Step 77200: loss_history = -783.0547485351562
# Step 77300: loss_history = -783.332763671875
# Step 77400: loss_history = -783.3070678710938
# Step 77500: loss_history = -783.6001586914062
# Step 77600: loss_history = -783.3922729492188
# Step 77700: loss_history = -783.2005615234375
# Step 77800: loss_history = -783.3159790039062
# Step 77900: loss_history = -783.1851806640625
# Step 78000: loss_history = -783.3649291992188
# Step 78100: loss_history = -783.696044921875
# Step 78200: loss_history = -783.4850463867188
# Step 78300: loss_history = -783.440673828125
# Step 78400: loss_history = -783.226806640625
# Step 78500: loss_history = -783.2598876953125
# Step 78600: loss_history = -783.4407348632812
# Step 78700: loss_history = -783.828369140625
# Step 78800: loss_history = -783.68310546875
# Step 78900: loss_history = -783.5301513671875
# Step 79000: loss_history = -783.4812622070312
# Step 79100: loss_history = -783.3612060546875
# Step 79200: loss_history = -783.872802734375
# Step 79300: loss_history = -783.9346313476562
# Step 79400: loss_history = -783.6552734375
# Step 79500: loss_history = -783.5084228515625
# Step 79600: loss_history = -783.6021728515625
# Step 79700: loss_history = -783.4843139648438
# Step 79800: loss_history = -783.676025390625
# Step 79900: loss_history = -783.8189697265625
# Step 80000: loss_history = -783.7920532226562
# Step 80100: loss_history = -783.6161499023438
# Step 80200: loss_history = -783.7454223632812
# Step 80300: loss_history = -783.7361450195312
# Step 80400: loss_history = -783.685791015625
# Step 80500: loss_history = -783.613525390625
# Step 80600: loss_history = -783.9063110351562
# Step 80700: loss_history = -783.8248291015625
# Step 80800: loss_history = -783.61181640625
# Step 80900: loss_history = -784.0343017578125
# Step 81000: loss_history = -783.8589477539062
# Step 81100: loss_history = -783.7772216796875
# Step 81200: loss_history = -783.8125610351562
# Step 81300: loss_history = -783.9746704101562
# Step 81400: loss_history = -782.7886352539062
# Step 81500: loss_history = -784.1005859375
# Step 81600: loss_history = -783.8983764648438
# Step 81700: loss_history = -783.7852172851562
# Step 81800: loss_history = -783.7678833007812
# Step 81900: loss_history = -783.9129028320312
# Step 82000: loss_history = -783.0202026367188
# Step 82100: loss_history = -784.2775268554688
# Step 82200: loss_history = -784.0719604492188
# Step 82300: loss_history = -783.9544677734375
# Step 82400: loss_history = -783.9972534179688
# Step 82500: loss_history = -784.0640869140625
# Step 82600: loss_history = -784.335205078125
# Step 82700: loss_history = -784.1905517578125
# Step 82800: loss_history = -784.1697387695312
# Step 82900: loss_history = -784.0280151367188
# Step 83000: loss_history = -784.390625
# Step 83100: loss_history = -784.2708740234375
# Step 83200: loss_history = -783.990966796875
# Step 83300: loss_history = -784.0399780273438
# Step 83400: loss_history = -784.1065673828125
# Step 83500: loss_history = -784.6248168945312
# Step 83600: loss_history = -784.6657104492188
# Step 83700: loss_history = -784.41357421875
# Step 83800: loss_history = -784.22119140625
# Step 83900: loss_history = -784.1319580078125
# Step 84000: loss_history = -784.14013671875
# Step 84100: loss_history = -784.27734375
# Step 84200: loss_history = -784.572998046875
# Step 84300: loss_history = -784.6470336914062
# Step 84400: loss_history = -784.4832153320312
# Step 84500: loss_history = -784.3411865234375
# Step 84600: loss_history = -784.32763671875
# Step 84700: loss_history = -784.48974609375
# Step 84800: loss_history = -784.3674926757812
# Step 84900: loss_history = -784.8509521484375
# Step 85000: loss_history = -784.6246337890625
# Step 85100: loss_history = -784.4739379882812
# Step 85200: loss_history = -784.41748046875
# Step 85300: loss_history = -784.23974609375
# Step 85400: loss_history = -784.6826171875
# Step 85500: loss_history = -783.551025390625
# Step 85600: loss_history = -784.7203979492188
# Step 85700: loss_history = -784.5147094726562
# Step 85800: loss_history = -784.51513671875
# Step 85900: loss_history = -784.4672241210938
# Step 86000: loss_history = -784.6722412109375
# Step 86100: loss_history = -784.9622802734375
# Step 86200: loss_history = -784.234619140625
# Step 86300: loss_history = -784.7675170898438
# Step 86400: loss_history = -784.6981201171875
# Step 86500: loss_history = -784.4555053710938
# Step 86600: loss_history = -784.8709106445312
# Step 86700: loss_history = -784.698486328125
# Step 86800: loss_history = -784.7568969726562
# Step 86900: loss_history = -784.57373046875
# Step 87000: loss_history = -784.4378662109375
# Step 87100: loss_history = -785.0933837890625
# Step 87200: loss_history = -785.2015991210938
# Step 87300: loss_history = -785.0142822265625
# Step 87400: loss_history = -784.7410888671875
# Step 87500: loss_history = -784.6898803710938
# Step 87600: loss_history = -784.765380859375
# Step 87700: loss_history = -784.98486328125
# Step 87800: loss_history = -784.3145751953125
# Step 87900: loss_history = -785.1560668945312
# Step 88000: loss_history = -784.9507446289062
# Step 88100: loss_history = -784.6912231445312
# Step 88200: loss_history = -784.6727294921875
# Step 88300: loss_history = -785.0271606445312
# Step 88400: loss_history = -785.0009765625
# Step 88500: loss_history = -785.2124633789062
# Step 88600: loss_history = -785.0859375
# Step 88700: loss_history = -784.7824096679688
# Step 88800: loss_history = -785.00732421875
# Step 88900: loss_history = -785.0743408203125
# Step 89000: loss_history = -785.2753295898438
# Step 89100: loss_history = -785.2955932617188
# Step 89200: loss_history = -785.3724975585938
# Step 89300: loss_history = -785.04248046875
# Step 89400: loss_history = -785.047607421875
# Step 89500: loss_history = -785.0142211914062
# Step 89600: loss_history = -785.1087646484375
# Step 89700: loss_history = -785.31640625
# Step 89800: loss_history = -785.3386840820312
# Step 89900: loss_history = -785.3722534179688
# Step 90000: loss_history = -785.1919555664062
# Step 90100: loss_history = -785.0787353515625
# Step 90200: loss_history = -785.2213745117188
# Step 90300: loss_history = -785.09765625
# Step 90400: loss_history = -785.3124389648438
# Step 90500: loss_history = -785.356201171875
# Step 90600: loss_history = -785.4105834960938
# Step 90700: loss_history = -785.3320922851562
# Step 90800: loss_history = -785.2220458984375
# Step 90900: loss_history = -785.0687255859375
# Step 91000: loss_history = -785.1099853515625
# Step 91100: loss_history = -785.3308715820312
# Step 91200: loss_history = -785.3214721679688
# Step 91300: loss_history = -785.64599609375
# Step 91400: loss_history = -785.3649291992188
# Step 91500: loss_history = -785.2832641601562
# Step 91600: loss_history = -785.2754516601562
# Step 91700: loss_history = -785.1360473632812
# Step 91800: loss_history = -785.4793701171875
# Step 91900: loss_history = -785.8106689453125
# Step 92000: loss_history = -785.5960693359375
# Step 92100: loss_history = -785.413330078125
# Step 92200: loss_history = -785.3472900390625
# Step 92300: loss_history = -785.1593017578125
# Step 92400: loss_history = -785.2806396484375
# Step 92500: loss_history = -785.5442504882812
# Step 92600: loss_history = -785.137939453125
# Step 92700: loss_history = -785.65771484375
# Step 92800: loss_history = -785.6400146484375
# Step 92900: loss_history = -785.2864379882812
# Step 93000: loss_history = -785.4030151367188
# Step 93100: loss_history = -785.6263427734375
# Step 93200: loss_history = -785.6240844726562
# Step 93300: loss_history = -785.1802368164062
# Step 93400: loss_history = -785.748779296875
# Step 93500: loss_history = -785.5784301757812
# Step 93600: loss_history = -785.3369750976562
# Step 93700: loss_history = -785.5596313476562
# Step 93800: loss_history = -785.7286376953125
# Step 93900: loss_history = -785.7129516601562
# Step 94000: loss_history = -786.0719604492188
# Step 94100: loss_history = -785.866943359375
# Step 94200: loss_history = -785.6951293945312
# Step 94300: loss_history = -785.5904541015625
# Step 94400: loss_history = -785.6806640625
# Step 94500: loss_history = -785.5916748046875
# Step 94600: loss_history = -786.0989379882812
# Step 94700: loss_history = -785.647216796875
# Step 94800: loss_history = -785.9683837890625
# Step 94900: loss_history = -785.6851806640625
# Step 95000: loss_history = -785.6028442382812
# Step 95100: loss_history = -785.599609375
# Step 95200: loss_history = -785.9313354492188
# Step 95300: loss_history = -785.9847412109375
# Step 95400: loss_history = -785.1622924804688
# Step 95500: loss_history = -786.1190185546875
# Step 95600: loss_history = -785.8032836914062
# Step 95700: loss_history = -785.7654418945312
# Step 95800: loss_history = -785.7173461914062
# Step 95900: loss_history = -785.8175048828125
# Step 96000: loss_history = -786.013916015625
# Step 96100: loss_history = -786.1358032226562
# Step 96200: loss_history = -786.1810302734375
# Step 96300: loss_history = -785.85498046875
# Step 96400: loss_history = -785.7818603515625
# Step 96500: loss_history = -785.8922729492188
# Step 96600: loss_history = -785.7644653320312
# Step 96700: loss_history = -786.1846923828125
# Step 96800: loss_history = -786.2373046875
# Step 96900: loss_history = -786.3507690429688
# Step 97000: loss_history = -786.0249633789062
# Step 97100: loss_history = -785.9410400390625
# Step 97200: loss_history = -785.9022216796875
# Step 97300: loss_history = -785.9127197265625
# Step 97400: loss_history = -786.0830078125
# Step 97500: loss_history = -786.0968017578125
# Step 97600: loss_history = -786.4586181640625
# Step 97700: loss_history = -786.1217041015625
# Step 97800: loss_history = -786.0130615234375
# Step 97900: loss_history = -786.0701293945312
# Step 98000: loss_history = -785.9117431640625
# Step 98100: loss_history = -786.2467651367188
# Step 98200: loss_history = -786.0182495117188
# Step 98300: loss_history = -786.3046875
# Step 98400: loss_history = -786.4533081054688
# Step 98500: loss_history = -786.2098388671875
# Step 98600: loss_history = -786.0972290039062
# Step 98700: loss_history = -786.09326171875
# Step 98800: loss_history = -786.2138061523438
# Step 98900: loss_history = -786.1854248046875
# Step 99000: loss_history = -786.447509765625
# Step 99100: loss_history = -786.513671875
# Step 99200: loss_history = -786.43603515625
# Step 99300: loss_history = -786.1934204101562
# Step 99400: loss_history = -786.1170654296875
# Step 99500: loss_history = -786.171630859375
# Step 99600: loss_history = -786.099853515625
# Step 99700: loss_history = -786.2955932617188
# Step 99800: loss_history = -786.4841918945312
# Step 99900: loss_history = -786.556884765625
# Step 100000: loss_history = -786.4282836914062
# Step 100100: loss_history = -786.215576171875
# Step 100200: loss_history = -786.1873168945312
# Step 100300: loss_history = -786.0740966796875
# Step 100400: loss_history = -786.298583984375
# Step 100500: loss_history = -784.9267578125
# Step 100600: loss_history = -786.7063598632812
# Step 100700: loss_history = -786.5453491210938
# Step 100800: loss_history = -786.3095703125
# Step 100900: loss_history = -786.2346801757812
# Step 101000: loss_history = -786.325439453125
# Step 101100: loss_history = -786.4622802734375
# Step 101200: loss_history = -786.5408325195312
# Step 101300: loss_history = -786.2606811523438
# Step 101400: loss_history = -786.6193237304688
# Step 101500: loss_history = -786.4484252929688
# Step 101600: loss_history = -786.3490600585938
# Step 101700: loss_history = -786.37255859375
# Step 101800: loss_history = -786.494873046875
# Step 101900: loss_history = -786.4596557617188
# Step 102000: loss_history = -786.7634887695312
# Step 102100: loss_history = -786.82177734375
# Step 102200: loss_history = -786.7214965820312
# Step 102300: loss_history = -786.5274658203125
# Step 102400: loss_history = -786.463134765625
# Step 102500: loss_history = -786.5289306640625
# Step 102600: loss_history = -786.4528198242188
# Step 102700: loss_history = -786.6873168945312
# Step 102800: loss_history = -785.2815551757812
# Step 102900: loss_history = -786.951416015625
# Step 103000: loss_history = -786.7000732421875
# Step 103100: loss_history = -786.473876953125
# Step 103200: loss_history = -786.5743408203125
# Step 103300: loss_history = -786.691162109375
# Step 103400: loss_history = -786.6005859375
# Step 103500: loss_history = -786.7005615234375
# ...
# Step 469600: loss_history = -791.653564453125
# Step 469700: loss_history = -792.7954711914062
# Step 469800: loss_history = -793.2562866210938
# Step 469900: loss_history = -793.0604248046875
# Step 470000: loss_history = -792.998046875
# Step 470100: loss_history = -792.9171142578125
# Step 470200: loss_history = -792.8939819335938
# Step 470300: loss_history = -792.883056640625
# Step 470400: loss_history = -792.7113037109375
# Step 470500: loss_history = -792.7421875
# Step 470600: loss_history = -792.7447509765625
# Step 470700: loss_history = -792.8355102539062
# Step 470800: loss_history = -792.9450073242188
# Step 470900: loss_history = -792.8086547851562
# Step 471000: loss_history = -792.9816284179688
# Step 471100: loss_history = -793.1111450195312
# Step 471200: loss_history = -792.493408203125
# Step 471300: loss_history = -793.2509765625
# Step 471400: loss_history = -793.1689453125
# Step 471500: loss_history = -793.0958862304688
# Step 471600: loss_history = -793.0504760742188
# Step 471700: loss_history = -792.8655395507812
# Step 471800: loss_history = -792.8447265625
# Step 471900: loss_history = -792.80126953125
# Step 472000: loss_history = -792.8292236328125
# Step 472100: loss_history = -792.8721313476562
# Step 472200: loss_history = -792.7161254882812
# Step 472300: loss_history = -792.8109130859375
# Step 472400: loss_history = -792.8704223632812
# Step 472500: loss_history = -793.0387573242188
# Step 472600: loss_history = -793.2300415039062
# Step 472700: loss_history = -793.117919921875
# Step 472800: loss_history = -792.3817138671875
# Step 472900: loss_history = -793.1876831054688
# Step 473000: loss_history = -793.1075439453125
# Step 473100: loss_history = -793.0109252929688
# Step 473200: loss_history = -792.9662475585938
# Step 473300: loss_history = -792.9327392578125
# Step 473400: loss_history = -792.7542724609375
# Step 473500: loss_history = -792.7582397460938
# Step 473600: loss_history = -792.7368774414062
# Step 473700: loss_history = -792.7948608398438
# Step 473800: loss_history = -792.869384765625
# Step 473900: loss_history = -792.7228393554688
# Step 474000: loss_history = -792.85498046875
# Step 474100: loss_history = -793.03369140625
# Step 474200: loss_history = -793.1631469726562
# Step 474300: loss_history = -791.9544067382812
# Step 474400: loss_history = -793.3028564453125
# Step 474500: loss_history = -793.2208251953125
# Step 474600: loss_history = -793.1478271484375
# Step 474700: loss_history = -792.9573364257812
# Step 474800: loss_history = -792.914794921875
# Step 474900: loss_history = -792.851806640625
# Step 475000: loss_history = -792.85302734375
# Step 475100: loss_history = -792.8680419921875
# Step 475200: loss_history = -792.7036743164062
# Step 475300: loss_history = -792.7651977539062
# Step 475400: loss_history = -792.794921875
# Step 475500: loss_history = -792.9227905273438
# Step 475600: loss_history = -793.0711059570312
# Step 475700: loss_history = -792.9465942382812
# Step 475800: loss_history = -793.1657104492188
# Step 475900: loss_history = -793.04345703125
# Step 476000: loss_history = -793.2403564453125
# Step 476100: loss_history = -793.1293334960938
# Step 476200: loss_history = -793.0652465820312
# Step 476300: loss_history = -793.0110473632812
# Step 476400: loss_history = -792.826416015625
# Step 476500: loss_history = -792.8062744140625
# Step 476600: loss_history = -792.76318359375
# Step 476700: loss_history = -792.7913818359375
# Step 476800: loss_history = -792.8504638671875
# Step 476900: loss_history = -792.9249877929688
# Step 477000: loss_history = -792.7785034179688
# Step 477100: loss_history = -792.910400390625
# Step 477200: loss_history = -793.0033569335938
# Step 477300: loss_history = -793.21728515625
# Step 477400: loss_history = -791.682861328125
# Step 477500: loss_history = -792.815673828125
# Step 477600: loss_history = -793.2688598632812
# Step 477700: loss_history = -793.0736083984375
# Step 477800: loss_history = -793.0114135742188
# Step 477900: loss_history = -792.9310302734375
# Step 478000: loss_history = -792.9083862304688
# Step 478100: loss_history = -792.8981323242188
# Step 478200: loss_history = -792.7265014648438
# Step 478300: loss_history = -792.7581176757812
# Step 478400: loss_history = -792.7610473632812
# Step 478500: loss_history = -792.8525390625
# Step 478600: loss_history = -792.9622192382812
# Step 478700: loss_history = -792.8262329101562
# Step 478800: loss_history = -792.9998168945312
# Step 478900: loss_history = -793.1298828125
# Step 479000: loss_history = -792.4334716796875
# Step 479100: loss_history = -793.2703857421875
# Step 479200: loss_history = -793.188720703125
# Step 479300: loss_history = -793.1160888671875
# Step 479400: loss_history = -792.926025390625
# Step 479500: loss_history = -792.8840942382812
# Step 479600: loss_history = -792.8214721679688
# Step 479700: loss_history = -792.8230590820312
# Step 479800: loss_history = -792.852294921875
# Step 479900: loss_history = -792.8956909179688
# Step 480000: loss_history = -792.740234375
# Step 480100: loss_history = -792.8352661132812
# Step 480200: loss_history = -792.8951416015625
# Step 480300: loss_history = -793.0639038085938
# Step 480400: loss_history = -793.2556762695312
# Step 480500: loss_history = -793.1439819335938
# Step 480600: loss_history = -792.2296142578125
# Step 480700: loss_history = -793.2144775390625
# Step 480800: loss_history = -793.134765625
# Step 480900: loss_history = -793.0385131835938
# Step 481000: loss_history = -792.994140625
# Step 481100: loss_history = -792.9609985351562
# Step 481200: loss_history = -792.7825927734375
# Step 481300: loss_history = -792.7872924804688
# Step 481400: loss_history = -792.7661743164062
# Step 481500: loss_history = -792.8245239257812
# Step 481600: loss_history = -792.8994750976562
# Step 481700: loss_history = -792.7534790039062
# Step 481800: loss_history = -792.8858032226562
# Step 481900: loss_history = -792.9791870117188
# Step 482000: loss_history = -793.193603515625
# Step 482100: loss_history = -792.043212890625
# Step 482200: loss_history = -793.17822265625
# Step 482300: loss_history = -793.2461547851562
# Step 482400: loss_history = -793.0511474609375
# Step 482500: loss_history = -792.9894409179688
# Step 482600: loss_history = -792.9091186523438
# Step 482700: loss_history = -792.8869018554688
# Step 482800: loss_history = -792.8767700195312
# Step 482900: loss_history = -792.7053833007812
# Step 483000: loss_history = -792.740966796875
# Step 483100: loss_history = -792.8026123046875
# Step 483200: loss_history = -792.8326416015625
# Step 483300: loss_history = -792.9608154296875
# Step 483400: loss_history = -793.1096801757812
# Step 483500: loss_history = -792.9851684570312
# Step 483600: loss_history = -793.204833984375
# Step 483700: loss_history = -792.7382202148438
# Step 483800: loss_history = -793.2801513671875
# Step 483900: loss_history = -793.1693725585938
# Step 484000: loss_history = -793.1057739257812
# Step 484100: loss_history = -793.0520629882812
# Step 484200: loss_history = -792.8674926757812
# Step 484300: loss_history = -792.847900390625
# Step 484400: loss_history = -792.8050537109375
# Step 484500: loss_history = -792.8338012695312
# Step 484600: loss_history = -792.87744140625
# Step 484700: loss_history = -792.7222290039062
# Step 484800: loss_history = -792.8175659179688
# Step 484900: loss_history = -792.8778076171875
# Step 485000: loss_history = -793.0469970703125
# Step 485100: loss_history = -793.2391967773438
# Step 485200: loss_history = -793.1277465820312
# Step 485300: loss_history = -792.5066528320312
# Step 485400: loss_history = -793.1988525390625
# Step 485500: loss_history = -793.1194458007812
# Step 485600: loss_history = -793.0232543945312
# Step 485700: loss_history = -792.9794921875
# Step 485800: loss_history = -792.9465942382812
# Step 485900: loss_history = -792.7686767578125
# Step 486000: loss_history = -792.773193359375
# Step 486100: loss_history = -792.7526245117188
# Step 486200: loss_history = -792.8112182617188
# Step 486300: loss_history = -792.8865356445312
# Step 486400: loss_history = -792.7410278320312
# Step 486500: loss_history = -792.8735961914062
# Step 486600: loss_history = -792.8942260742188
# Step 486700: loss_history = -792.9154663085938
# Step 486800: loss_history = -792.743896484375
# Step 486900: loss_history = -792.7758178710938
# Step 487000: loss_history = -792.779296875
# Step 487100: loss_history = -792.87109375
# Step 487200: loss_history = -792.9813232421875
# Step 487300: loss_history = -792.8457641601562
# Step 487400: loss_history = -793.01953125
# Step 487500: loss_history = -793.1500244140625
# Step 487600: loss_history = -792.3575439453125
# Step 487700: loss_history = -793.2914428710938
# Step 487800: loss_history = -793.210205078125
# Step 487900: loss_history = -793.1378784179688
# Step 488000: loss_history = -792.9482421875
# Step 488100: loss_history = -792.90673828125
# Step 488200: loss_history = -792.8442993164062
# Step 488300: loss_history = -792.8463134765625
# Step 488400: loss_history = -792.8619384765625
# Step 488500: loss_history = -792.6984252929688
# Step 488600: loss_history = -792.760498046875
# Step 488700: loss_history = -792.7909545898438
# Step 488800: loss_history = -792.9195556640625
# Step 488900: loss_history = -793.0686645507812
# Step 489000: loss_history = -793.2820434570312
# Step 489100: loss_history = -793.1709594726562
# Step 489200: loss_history = -792.0790405273438
# Step 489300: loss_history = -793.2420043945312
# Step 489400: loss_history = -793.1624755859375
# Step 489500: loss_history = -793.0662841796875
# Step 489600: loss_history = -793.0223388671875
# Step 489700: loss_history = -792.989501953125
# Step 489800: loss_history = -792.8114013671875
# Step 489900: loss_history = -792.8162231445312
# Step 490000: loss_history = -792.7954711914062
# Step 490100: loss_history = -792.8543090820312
# Step 490200: loss_history = -792.9295043945312
# Step 490300: loss_history = -792.7837524414062
# Step 490400: loss_history = -792.91650390625
# Step 490500: loss_history = -793.01025390625
# Step 490600: loss_history = -793.2249755859375
# Step 490700: loss_history = -791.83984375
# Step 490800: loss_history = -792.96923828125
# Step 490900: loss_history = -793.2786865234375
# Step 491000: loss_history = -793.0839233398438
# Step 491100: loss_history = -793.0224609375
# Step 491200: loss_history = -792.9425048828125
# Step 491300: loss_history = -792.92041015625
# Step 491400: loss_history = -792.9107666015625
# Step 491500: loss_history = -792.7396850585938
# Step 491600: loss_history = -792.7719116210938
# Step 491700: loss_history = -792.7755737304688
# Step 491800: loss_history = -792.8673706054688
# Step 491900: loss_history = -792.9778442382812
# Step 492000: loss_history = -792.842529296875
# Step 492100: loss_history = -793.0166015625
# Step 492200: loss_history = -793.1471557617188
# Step 492300: loss_history = -792.4757690429688
# Step 492400: loss_history = -793.2888793945312
# Step 492500: loss_history = -793.2077026367188
# Step 492600: loss_history = -793.1356811523438
# Step 492700: loss_history = -792.9461669921875
# Step 492800: loss_history = -792.9047241210938
# Step 492900: loss_history = -792.8425903320312
# Step 493000: loss_history = -792.8447875976562
# Step 493100: loss_history = -792.8605346679688
# Step 493200: loss_history = -792.91845703125
# Step 493300: loss_history = -792.763671875
# Step 493400: loss_history = -792.8592529296875
# Step 493500: loss_history = -792.9197998046875
# Step 493600: loss_history = -793.0889282226562
# Step 493700: loss_history = -793.28125
# Step 493800: loss_history = -793.1699829101562
# Step 493900: loss_history = -792.1712646484375
# Step 494000: loss_history = -793.24169921875
# Step 494100: loss_history = -793.1624755859375
# Step 494200: loss_history = -793.0668334960938
# Step 494300: loss_history = -793.0230712890625
# Step 494400: loss_history = -792.9903564453125
# Step 494500: loss_history = -792.8129272460938
# Step 494600: loss_history = -792.81787109375
# Step 494700: loss_history = -792.7974243164062
# Step 494800: loss_history = -792.8563232421875
# Step 494900: loss_history = -792.93212890625
# Step 495000: loss_history = -792.7866821289062
# Step 495100: loss_history = -792.9194946289062
# Step 495200: loss_history = -793.0135498046875
# Step 495300: loss_history = -793.2284545898438
# Step 495400: loss_history = -791.878662109375
# Step 495500: loss_history = -793.0035400390625
# Step 495600: loss_history = -793.282958984375
# Step 495700: loss_history = -793.088623046875
# Step 495800: loss_history = -793.0275268554688
# Step 495900: loss_history = -792.9476928710938
# Step 496000: loss_history = -792.926025390625
# Step 496100: loss_history = -792.9164428710938
# Step 496200: loss_history = -792.745849609375
# Step 496300: loss_history = -792.7783203125
# Step 496400: loss_history = -792.7822265625
# Step 496500: loss_history = -792.8743896484375
# Step 496600: loss_history = -792.985107421875
# Step 496700: loss_history = -792.8501586914062
# Step 496800: loss_history = -793.0244750976562
# Step 496900: loss_history = -793.1554565429688
# Step 497000: loss_history = -792.4608764648438
# Step 497100: loss_history = -793.2979125976562
# Step 497200: loss_history = -793.217041015625
# Step 497300: loss_history = -793.1453247070312
# Step 497400: loss_history = -792.9560546875
# Step 497500: loss_history = -792.9149169921875
# Step 497600: loss_history = -792.85302734375
# Step 497700: loss_history = -792.8554077148438
# Step 497800: loss_history = -792.8715209960938
# Step 497900: loss_history = -792.70849609375
# Step 498000: loss_history = -792.7710571289062
# Step 498100: loss_history = -792.802001953125
# Step 498200: loss_history = -792.93115234375
# Step 498300: loss_history = -793.0807495117188
# Step 498400: loss_history = -793.294677734375
# Step 498500: loss_history = -793.183837890625
# Step 498600: loss_history = -792.0926513671875
# Step 498700: loss_history = -793.2557983398438
# Step 498800: loss_history = -793.1770629882812
# Step 498900: loss_history = -793.0814819335938
# Step 499000: loss_history = -793.0379638671875
# Step 499100: loss_history = -793.0054321289062
# Step 499200: loss_history = -792.828125
# Step 499300: loss_history = -792.8333740234375
# Step 499400: loss_history = -792.813232421875
# Step 499500: loss_history = -792.8724365234375
# Step 499600: loss_history = -792.9484252929688
# Step 499700: loss_history = -792.8031616210938
# Step 499800: loss_history = -792.9364013671875
# Step 499900: loss_history = -793.0305786132812
# Optimized Coordinates:
# Vertex 1: (-17.9581241607666, -3.7146973609924316)
# Vertex 2: (-18.4154109954834, -0.2254701405763626)
# Vertex 3: (-18.096542358398438, 3.274113416671753)
# Vertex 4: (-17.02157211303711, 6.612976551055908)
# Vertex 5: (-15.263564109802246, 9.607623100280762)
# Vertex 6: (-12.969616889953613, 12.089141845703125)
# Vertex 7: (-10.318530082702637, 13.96707820892334)
# Vertex 8: (-7.461119174957275, 15.229193687438965)
# Vertex 9: (-4.4975104331970215, 15.898591041564941)
# Vertex 10: (-1.487623929977417, 15.99530029296875)
# Vertex 11: (1.4669700860977173, 15.52970027923584)
# Vertex 12: (4.200295925140381, 14.559213638305664)
# Vertex 13: (6.586521625518799, 13.19804573059082)
# Vertex 14: (8.577460289001465, 11.570253372192383)
# Vertex 15: (10.189807891845703, 9.763322830200195)
# Vertex 16: (11.463046073913574, 7.817256927490234)
# Vertex 17: (12.425436973571777, 5.743132591247559)
# Vertex 18: (13.081707954406738, 3.5492753982543945)
# Vertex 19: (13.418328285217285, 1.2631525993347168)
# Vertex 20: (13.419968605041504, -1.0632597208023071)
# Vertex 21: (13.084235191345215, -3.360081911087036)
# Vertex 22: (12.413789749145508, -5.595471382141113)
# Vertex 23: (11.39788818359375, -7.754817962646484)
# Vertex 24: (10.002886772155762, -9.823911666870117)
# Vertex 25: (8.17760181427002, -11.762459754943848)
# Vertex 26: (5.884197235107422, -13.476819038391113)
# Vertex 27: (3.1464669704437256, -14.820640563964844)
# Vertex 28: (0.07974793016910553, -15.63969612121582)
# Vertex 29: (-3.1413145065307617, -15.83372688293457)
# Vertex 30: (-6.345760822296143, -15.372489929199219)
# Vertex 31: (-9.4461088180542, -14.246018409729004)
# Vertex 32: (-12.323171615600586, -12.446415901184082)
# Vertex 33: (-14.813361167907715, -10.006305694580078)
# Vertex 34: (-16.73685073852539, -7.036735534667969)
# Optimized Perimeter: 99.9935
# Optimized Area: 793.2458
# Theoretical maximum = (aprox 795)

# %%
plt.plot(loss_history)
plt.grid(True)
plt.xlabel("iteration")
plt.ylabel("loss")
plt.title("loss history - 34 Point Optimizer ")
plt.savefig("loss_history_34_Adam_500000its_lr0.0008.pdf")
